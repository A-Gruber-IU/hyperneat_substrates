# %% [markdown]
# # Problem-Specific Coordinate Generation for HyperNEAT Substrates

# %% [markdown]
# ## Setup
#
# The testing was done on a 16GB VRAM GPU with CUDA 12.8. VRAM usage is determined mainly by substrate and population size.

# %% [markdown]
# ### Imports
#
# This setup requires some dependencies, mainly TensorNEAT, JAX, numpy, matplotlib, NetworkX, scikit-learn and wandb for logging. Using a virtual environment (i.e. conda) is highly recommended. Python 3.10.18 was used in development and testing.

# %%
import wandb
import pickle

from config import config
from evol_pipeline.custom_pipeline import CustomPipeline
from utils.visualization import visualize_cppn, visualize_nn
from utils.utils import setup_folder_structure
from evol_pipeline.evol_algorithm import create_evol_algorithm
from evol_pipeline.brax_env import CustomBraxEnv

# %% [markdown]
# A quick setup of the folder structure to avoid errors further down the line.

# %%
OUTPUT_DIR = config["experiment"]["output_dir"]
setup_folder_structure(OUTPUT_DIR)

with open(f"{OUTPUT_DIR}/substrates.pkl", "rb") as f:
    substrates = pickle.load(f)

env_name = config["experiment"]["env_name"]
env_problem = CustomBraxEnv(
    env_name=env_name,
    backend=config["environment"]["backend"],
    brax_args=config["environment"]["brax_args"],
    max_step=config["environment"]["max_step"],
    repeat_times=config["environment"]["repeat_times"],
    obs_normalization=False,
    sample_episodes=16,
)
obs_size = env_problem.input_shape[0]
act_size = env_problem.output_shape[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 OUTPUT_DIR = config["experiment"]["output_dir"]
#       2 setup_folder_structure(OUTPUT_DIR)
# ----> 4 with open(f"{OUTPUT_DIR}/substrates.pkl", "rb") as f:
#       5     substrates = pickle.load(f)
#       7 env_name = config["experiment"]["env_name"]
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/ant/substrates.pkl'

# %% [markdown]
# ## Neuroevolution
#
# Finally the substrates are ready to be used for neuroevolution.

# %%
for data_label, data_dict in substrates.items():
    for method_label, method_dict in data_dict.items():

        active_substrate = substrates[data_label][method_label]["substrate"]
        evol_algorithm = create_evol_algorithm(substrate=active_substrate)

        wanbd_name = f"{env_name}_{data_label}_{method_label}"
        wandb_tags = [config["substrate"]["hidden_layer_type"], env_name, data_label, method_label]

        wandb.init(
            name=wanbd_name,
            project="substrate_dims",
            tags=wandb_tags,
            config=config  
        )

        wandb.config.update({
            "substrate": {
                "obs_size": obs_size,
                "act_size": act_size,
                "substrate.query_coors.shape": active_substrate.query_coors.shape, # (num_queries, query_dim)
                "algorithm.num_inputs": evol_algorithm.num_inputs,
                }
            }
        )

        pipeline = CustomPipeline(
            algorithm=evol_algorithm,
            problem=env_problem,
            seed=config["experiment"]["seed"],
            generation_limit=config["evolution"]["generation_limit"],
            fitness_target=config["evolution"]["fitness_target"],
            is_save=False,
            save_dir=config["experiment"]["output_dir"],
        )

        init_state = pipeline.setup()
        state = pipeline.auto_run(state=init_state)

        print(f"\nTraining finished. Best fitness achieved: {pipeline.best_fitness}")

        wandb.finish()

        state_for_show = state[0] if isinstance(state, tuple) else state

        # Transform the best genome into network parameters
        best_genome = pipeline.best_genome

        # Built-in show method to produce and save video
        pipeline.show(
            state=state_for_show,
            best=best_genome,
            output_type="mp4",
            save_path=f"{OUTPUT_DIR}/video/agent_{data_label}_{method_label}.mp4",
        )

        input_coors = substrates[data_label][method_label]["input_coors"]
        hidden_coors = substrates[data_label][method_label]["hidden_coors"]
        output_coors = substrates[data_label][method_label]["output_coors"]
        visualize_cppn(pipeline, state, f"{OUTPUT_DIR}/topology/cppn_{data_label}_{method_label}.svg")
        visualize_nn(pipeline, state, f"{OUTPUT_DIR}/topology/nn_{data_label}_{method_label}.svg", active_substrate, input_coors, hidden_coors, output_coors, config["substrate"]["hidden_depth"])
# Out:
# wandb: Currently logged in as: wirkelzirkel (wirkelzirkel-iu) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/andi/Dokumente/Bachelorarbeit/dim_tuning/wandb/run-20250907_130333-wrsknyd8</code>
# Syncing run <strong><a href='https://wandb.ai/wirkelzirkel-iu/substrate_dims/runs/wrsknyd8' target="_blank">ant_manual_simple</a></strong> to <a href='https://wandb.ai/wirkelzirkel-iu/substrate_dims' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/wirkelzirkel-iu/substrate_dims' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_dims</a>
#  View run at <a href='https://wandb.ai/wirkelzirkel-iu/substrate_dims/runs/wrsknyd8' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_dims/runs/wrsknyd8</a>
# initializing
# initializing finished
# start compile
# compile finished, cost time: 22.812298s
# Generation: 1, Cost time: 8801.63ms
#  	fitness: valid cnt: 600, max: 22.7817, min: -171.5821, mean: -50.7192, std: 43.2601
#
# 	node counts: max: 7, min: 5, mean: 6.09
#  	conn counts: max: 7, min: 0, mean: 4.70
#  	species: 15, [260, 3, 90, 4, 1, 2, 1, 38, 1, 63, 2, 1, 1, 13, 120]
#
# Generation: 2, Cost time: 8869.04ms
#  	fitness: valid cnt: 600, max: 122.0548, min: -313.4383, mean: -24.5565, std: 40.8689
#
# 	node counts: max: 8, min: 5, mean: 6.09
#  	conn counts: max: 8, min: 0, mean: 4.17
#  	species: 15, [93, 49, 117, 48, 77, 24, 16, 23, 14, 3, 9, 5, 5, 2, 115]
#
# Generation: 3, Cost time: 8846.00ms
#  	fitness: valid cnt: 600, max: 132.6757, min: -193.0689, mean: -15.7432, std: 35.8492
#
# 	node counts: max: 8, min: 5, mean: 6.17
#  	conn counts: max: 8, min: 0, mean: 4.17
#  	species: 15, [53, 72, 34, 61, 39, 28, 24, 76, 21, 16, 24, 14, 12, 4, 122]
#
# Generation: 4, Cost time: 8836.82ms
#  	fitness: valid cnt: 600, max: 136.6578, min: -198.6212, mean: -13.9126, std: 36.3642
#
# 	node counts: max: 9, min: 5, mean: 6.21
#  	conn counts: max: 8, min: 0, mean: 4.24
#  	species: 15, [22, 68, 9, 52, 22, 86, 27, 31, 60, 21, 23, 17, 18, 9, 135]
#
# Generation: 5, Cost time: 8891.51ms
#  	fitness: valid cnt: 600, max: 156.8087, min: -182.7655, mean: -11.5239, std: 40.1913
#
# 	node counts: max: 9, min: 5, mean: 6.22
#  	conn counts: max: 8, min: 0, mean: 4.15
#  	species: 15, [69, 28, 34, 68, 17, 34, 35, 27, 20, 56, 30, 15, 7, 12, 148]
#
# Generation: 6, Cost time: 8873.39ms
#  	fitness: valid cnt: 600, max: 169.5371, min: -265.4096, mean: -7.5081, std: 49.1433
#
# 	node counts: max: 9, min: 5, mean: 6.19
#  	conn counts: max: 8, min: 0, mean: 4.34
#  	species: 15, [81, 11, 45, 46, 1, 3, 59, 35, 27, 23, 14, 47, 24, 12, 172]
#
# Generation: 7, Cost time: 8918.21ms
#  	fitness: valid cnt: 600, max: 178.3573, min: -258.0158, mean: 0.0902, std: 48.5013
#
# 	node counts: max: 9, min: 5, mean: 6.12
#  	conn counts: max: 9, min: 0, mean: 4.18
#  	species: 15, [65, 71, 55, 47, 25, 28, 32, 2, 8, 31, 52, 25, 13, 12, 134]
#
# Generation: 8, Cost time: 8878.80ms
#  	fitness: valid cnt: 600, max: 175.4184, min: -344.5564, mean: 1.4813, std: 51.9022
#
# 	node counts: max: 9, min: 5, mean: 6.06
#  	conn counts: max: 9, min: 0, mean: 4.11
#  	species: 15, [71, 16, 49, 47, 15, 1, 29, 35, 31, 29, 43, 13, 52, 9, 160]
#
# Generation: 9, Cost time: 8918.57ms
#  	fitness: valid cnt: 600, max: 182.9604, min: -181.9007, mean: 1.2050, std: 46.8844
#
# 	node counts: max: 8, min: 5, mean: 6.00
#  	conn counts: max: 9, min: 0, mean: 4.08
#  	species: 15, [72, 39, 46, 49, 35, 1, 46, 31, 28, 38, 35, 12, 46, 9, 113]
#
# Generation: 10, Cost time: 8858.69ms
#  	fitness: valid cnt: 600, max: 189.7384, min: -165.3844, mean: 5.9193, std: 50.3826
#
# 	node counts: max: 8, min: 5, mean: 5.95
#  	conn counts: max: 8, min: 0, mean: 3.93
#  	species: 15, [56, 68, 34, 38, 46, 45, 49, 4, 28, 29, 37, 55, 12, 9, 90]
#
# Generation: 11, Cost time: 8892.14ms
#  	fitness: valid cnt: 600, max: 185.6502, min: -231.4893, mean: 8.7972, std: 54.1984
#
# 	node counts: max: 8, min: 5, mean: 5.93
#  	conn counts: max: 8, min: 0, mean: 3.78
#  	species: 15, [57, 63, 43, 43, 35, 33, 35, 34, 1, 43, 41, 67, 4, 9, 92]
#
# Generation: 12, Cost time: 8859.05ms
#  	fitness: valid cnt: 600, max: 246.9270, min: -219.0949, mean: 10.3517, std: 54.8114
#
# 	node counts: max: 8, min: 5, mean: 5.92
#  	conn counts: max: 8, min: 0, mean: 3.89
#  	species: 15, [57, 60, 43, 35, 3, 45, 45, 25, 28, 30, 44, 63, 13, 4, 105]
#
# Generation: 13, Cost time: 8896.52ms
#  	fitness: valid cnt: 600, max: 231.3810, min: -204.9975, mean: 10.4816, std: 54.2901
#
# 	node counts: max: 9, min: 5, mean: 6.17
#  	conn counts: max: 9, min: 0, mean: 4.28
#  	species: 15, [85, 1, 55, 22, 45, 32, 37, 27, 36, 36, 28, 47, 8, 16, 125]
#
# Generation: 14, Cost time: 8919.71ms
#  	fitness: valid cnt: 600, max: 241.0831, min: -385.9947, mean: 9.4763, std: 58.9755
#
# 	node counts: max: 9, min: 5, mean: 6.29
#  	conn counts: max: 9, min: 0, mean: 4.54
#  	species: 15, [2, 66, 32, 47, 51, 37, 30, 35, 44, 28, 20, 15, 43, 9, 141]
#
# Generation: 15, Cost time: 8961.31ms
#  	fitness: valid cnt: 600, max: 229.0304, min: -185.9737, mean: 7.7711, std: 61.0025
#
# 	node counts: max: 10, min: 5, mean: 6.38
#  	conn counts: max: 9, min: 0, mean: 4.67
#  	species: 15, [96, 32, 28, 49, 1, 40, 30, 41, 34, 28, 21, 13, 45, 11, 131]
#
# Generation: 16, Cost time: 8949.83ms
#  	fitness: valid cnt: 600, max: 258.2153, min: -232.9647, mean: 12.4501, std: 63.1015
#
# 	node counts: max: 9, min: 5, mean: 6.37
#  	conn counts: max: 9, min: 0, mean: 4.75
#  	species: 15, [82, 29, 2, 51, 52, 38, 38, 37, 26, 41, 25, 13, 37, 10, 119]
#
# Generation: 17, Cost time: 8960.30ms
#  	fitness: valid cnt: 600, max: 265.5745, min: -184.0221, mean: 18.8870, std: 66.0390
#
# 	node counts: max: 9, min: 5, mean: 6.41
#  	conn counts: max: 10, min: 0, mean: 4.89
#  	species: 15, [104, 44, 1, 44, 6, 42, 27, 42, 35, 34, 22, 31, 19, 10, 139]
#
# Generation: 18, Cost time: 8925.00ms
#  	fitness: valid cnt: 600, max: 269.5814, min: -203.2221, mean: 15.8133, std: 64.8271
#
# 	node counts: max: 9, min: 5, mean: 6.40
#  	conn counts: max: 10, min: 0, mean: 4.97
#  	species: 15, [41, 2, 25, 45, 86, 40, 44, 37, 35, 24, 21, 29, 12, 20, 139]
#
# Generation: 19, Cost time: 8964.36ms
#  	fitness: valid cnt: 600, max: 236.4777, min: -233.0369, mean: 15.1584, std: 63.9751
#
# 	node counts: max: 8, min: 5, mean: 6.41
#  	conn counts: max: 9, min: 0, mean: 4.98
#  	species: 15, [1, 103, 29, 43, 47, 22, 39, 38, 28, 30, 19, 36, 5, 11, 149]
#
# Generation: 20, Cost time: 8908.69ms
#  	fitness: valid cnt: 600, max: 278.4470, min: -216.7168, mean: 12.9870, std: 68.4592
#
# 	node counts: max: 9, min: 5, mean: 6.50
#  	conn counts: max: 9, min: 0, mean: 5.20
#  	species: 15, [40, 6, 53, 52, 36, 35, 40, 32, 29, 19, 30, 14, 8, 1, 205]
#
# Generation: 21, Cost time: 8965.38ms
#  	fitness: valid cnt: 600, max: 226.2575, min: -172.5613, mean: 16.6120, std: 65.5842
#
# 	node counts: max: 9, min: 5, mean: 6.41
#  	conn counts: max: 9, min: 0, mean: 4.81
#  	species: 15, [41, 67, 51, 56, 39, 45, 33, 39, 29, 18, 16, 14, 36, 1, 115]
#
# Generation: 22, Cost time: 8928.63ms
#  	fitness: valid cnt: 600, max: 244.7809, min: -169.1950, mean: 17.9720, std: 63.9898
#
# 	node counts: max: 9, min: 5, mean: 6.46
#  	conn counts: max: 9, min: 0, mean: 4.90
#  	species: 15, [36, 65, 11, 59, 30, 40, 52, 24, 35, 26, 19, 13, 30, 13, 147]
#
# Generation: 23, Cost time: 8943.36ms
#  	fitness: valid cnt: 600, max: 246.5905, min: -163.7300, mean: 14.8621, std: 67.0502
#
# 	node counts: max: 8, min: 5, mean: 6.38
#  	conn counts: max: 9, min: 0, mean: 4.65
#  	species: 15, [131, 61, 4, 41, 17, 12, 32, 33, 35, 24, 19, 18, 14, 8, 151]
#
# Generation: 24, Cost time: 8868.16ms
#  	fitness: valid cnt: 600, max: 262.2588, min: -227.9786, mean: 18.4175, std: 71.9627
#
# 	node counts: max: 9, min: 5, mean: 6.33
#  	conn counts: max: 9, min: 0, mean: 4.55
#  	species: 15, [5, 58, 45, 5, 45, 1, 39, 35, 27, 20, 32, 176, 11, 10, 91]
#
# Generation: 25, Cost time: 8922.60ms
#  	fitness: valid cnt: 600, max: 240.1734, min: -209.6384, mean: 15.6783, std: 65.4070
#
# 	node counts: max: 9, min: 5, mean: 6.24
#  	conn counts: max: 9, min: 0, mean: 4.39
#  	species: 15, [117, 72, 47, 4, 47, 45, 23, 36, 31, 23, 38, 12, 13, 4, 88]
#
# Generation: 26, Cost time: 8886.13ms
#  	fitness: valid cnt: 600, max: 256.9577, min: -186.4292, mean: 18.9967, std: 68.9427
#
# 	node counts: max: 9, min: 5, mean: 6.25
#  	conn counts: max: 9, min: 0, mean: 4.32
#  	species: 15, [92, 67, 3, 69, 28, 32, 45, 38, 23, 29, 43, 16, 8, 6, 101]
#
# Generation: 27, Cost time: 8922.94ms
#  	fitness: valid cnt: 600, max: 235.5099, min: -197.1154, mean: 16.1736, std: 67.1165
#
# 	node counts: max: 10, min: 5, mean: 6.42
#  	conn counts: max: 9, min: 0, mean: 4.80
#  	species: 15, [109, 85, 100, 2, 3, 30, 44, 38, 20, 13, 12, 29, 6, 1, 108]
#
# Generation: 28, Cost time: 8915.82ms
#  	fitness: valid cnt: 600, max: 270.7410, min: -369.5282, mean: 17.3334, std: 74.2179
#
# 	node counts: max: 10, min: 5, mean: 6.46
#  	conn counts: max: 9, min: 0, mean: 4.96
#  	species: 15, [84, 85, 2, 35, 37, 22, 50, 41, 36, 17, 17, 34, 17, 9, 114]
#
# Generation: 29, Cost time: 8947.56ms
#  	fitness: valid cnt: 600, max: 283.4019, min: -203.8506, mean: 12.7506, std: 67.4223
#
# 	node counts: max: 10, min: 5, mean: 6.43
#  	conn counts: max: 9, min: 0, mean: 4.90
#  	species: 15, [57, 85, 61, 41, 44, 1, 39, 24, 34, 18, 8, 11, 36, 10, 131]
#
# Generation: 30, Cost time: 8919.29ms
#  	fitness: valid cnt: 600, max: 255.8150, min: -203.0928, mean: 23.9458, std: 75.4745
#
# 	node counts: max: 9, min: 5, mean: 6.46
#  	conn counts: max: 10, min: 0, mean: 4.98
#  	species: 15, [82, 64, 59, 26, 11, 38, 42, 37, 18, 31, 13, 37, 10, 1, 131]
#
# Generation: 31, Cost time: 8926.50ms
#  	fitness: valid cnt: 600, max: 260.4631, min: -235.6450, mean: 21.5931, std: 71.4921
#
# 	node counts: max: 9, min: 5, mean: 6.45
#  	conn counts: max: 9, min: 0, mean: 4.92
#  	species: 15, [75, 56, 44, 68, 14, 41, 37, 34, 31, 23, 17, 35, 17, 11, 97]
#
# Generation: 32, Cost time: 8898.13ms
#  	fitness: valid cnt: 600, max: 246.8835, min: -193.2173, mean: 23.4383, std: 72.6948
#
# 	node counts: max: 9, min: 5, mean: 6.49
#  	conn counts: max: 9, min: 0, mean: 4.92
#  	species: 15, [66, 48, 38, 8, 56, 39, 38, 47, 31, 25, 25, 15, 21, 39, 104]
#
# Generation: 33, Cost time: 8923.74ms
#  	fitness: valid cnt: 600, max: 259.3719, min: -189.3394, mean: 25.0868, std: 73.4899
#
# 	node counts: max: 9, min: 5, mean: 6.53
#  	conn counts: max: 10, min: 0, mean: 4.93
#  	species: 15, [67, 58, 50, 51, 8, 44, 33, 32, 29, 30, 27, 16, 40, 3, 112]
#
# Generation: 34, Cost time: 8897.45ms
#  	fitness: valid cnt: 600, max: 270.7695, min: -170.1937, mean: 23.9892, std: 70.7641
#
# 	node counts: max: 10, min: 5, mean: 6.63
#  	conn counts: max: 10, min: 0, mean: 4.96
#  	species: 15, [54, 59, 58, 50, 8, 47, 30, 33, 29, 33, 26, 18, 10, 40, 105]
#
# Generation: 35, Cost time: 8948.48ms
#  	fitness: valid cnt: 600, max: 234.1136, min: -146.0629, mean: 23.8806, std: 71.6057
#
# 	node counts: max: 10, min: 5, mean: 6.69
#  	conn counts: max: 10, min: 0, mean: 5.22
#  	species: 15, [77, 64, 57, 38, 50, 51, 7, 29, 29, 28, 23, 19, 1, 10, 117]
#
# Generation: 36, Cost time: 8922.90ms
#  	fitness: valid cnt: 600, max: 263.6607, min: -204.3213, mean: 26.1580, std: 80.0154
#
# 	node counts: max: 10, min: 5, mean: 6.72
#  	conn counts: max: 10, min: 0, mean: 5.13
#  	species: 15, [73, 58, 61, 62, 52, 19, 39, 26, 28, 24, 19, 17, 10, 1, 111]
#
# Generation: 37, Cost time: 8951.50ms
#  	fitness: valid cnt: 600, max: 256.8092, min: -152.1828, mean: 28.4387, std: 76.6547
#
# 	node counts: max: 10, min: 5, mean: 6.81
#  	conn counts: max: 10, min: 0, mean: 5.08
#  	species: 15, [66, 59, 55, 41, 47, 16, 39, 25, 29, 29, 22, 37, 22, 9, 104]
#
# Generation: 38, Cost time: 8923.09ms
#  	fitness: valid cnt: 600, max: 265.2716, min: -151.0387, mean: 28.0450, std: 72.1449
#
# 	node counts: max: 10, min: 5, mean: 6.81
#  	conn counts: max: 10, min: 0, mean: 5.29
#  	species: 15, [73, 62, 6, 48, 59, 52, 22, 32, 30, 28, 20, 33, 21, 1, 113]
#
# Generation: 39, Cost time: 8952.56ms
#  	fitness: valid cnt: 600, max: 268.0023, min: -170.4348, mean: 26.1579, std: 73.9526
#
# 	node counts: max: 10, min: 5, mean: 6.75
#  	conn counts: max: 10, min: 0, mean: 5.21
#  	species: 15, [62, 54, 56, 58, 57, 38, 9, 21, 32, 29, 4, 21, 28, 10, 121]
#
# Generation: 40, Cost time: 8929.38ms
#  	fitness: valid cnt: 600, max: 284.3289, min: -187.5068, mean: 21.8691, std: 73.3003
#
# 	node counts: max: 10, min: 5, mean: 6.80
#  	conn counts: max: 12, min: 0, mean: 5.43
#  	species: 15, [54, 61, 51, 50, 53, 7, 39, 38, 30, 29, 13, 15, 27, 6, 127]
#
# Generation: 41, Cost time: 8951.31ms
#  	fitness: valid cnt: 600, max: 272.6790, min: -146.6685, mean: 23.4852, std: 72.7115
#
# 	node counts: max: 10, min: 5, mean: 6.75
#  	conn counts: max: 10, min: 0, mean: 5.28
#  	species: 15, [65, 95, 56, 48, 1, 41, 6, 35, 36, 27, 27, 13, 31, 10, 109]
#
# Generation: 42, Cost time: 8947.92ms
#  	fitness: valid cnt: 600, max: 269.6496, min: -174.0522, mean: 30.6348, std: 76.5835
#
# 	node counts: max: 10, min: 5, mean: 6.77
#  	conn counts: max: 10, min: 0, mean: 5.31
#  	species: 15, [96, 66, 55, 50, 10, 39, 40, 10, 29, 24, 23, 13, 30, 3, 112]
#
# Generation: 43, Cost time: 8987.86ms
#  	fitness: valid cnt: 600, max: 261.9724, min: -202.2510, mean: 24.6147, std: 78.2833
#
# 	node counts: max: 10, min: 5, mean: 6.74
#  	conn counts: max: 11, min: 0, mean: 5.34
#  	species: 15, [65, 21, 62, 23, 36, 69, 48, 30, 30, 26, 29, 22, 14, 24, 101]
#
# Generation: 44, Cost time: 8955.74ms
#  	fitness: valid cnt: 600, max: 254.6862, min: -176.6515, mean: 26.9559, std: 75.3428
#
# 	node counts: max: 10, min: 5, mean: 6.78
#  	conn counts: max: 11, min: 0, mean: 5.28
#  	species: 15, [99, 59, 56, 36, 4, 45, 36, 31, 25, 27, 24, 23, 33, 7, 95]
#
# Generation: 45, Cost time: 8950.15ms
#  	fitness: valid cnt: 600, max: 264.5229, min: -236.4751, mean: 25.6244, std: 79.9968
#
# 	node counts: max: 10, min: 5, mean: 6.93
#  	conn counts: max: 11, min: 0, mean: 5.31
#  	species: 15, [111, 46, 57, 4, 33, 60, 41, 31, 28, 24, 23, 6, 29, 4, 103]
#
# Generation: 46, Cost time: 8919.29ms
#  	fitness: valid cnt: 600, max: 272.3123, min: -201.3268, mean: 28.5071, std: 78.7758
#
# 	node counts: max: 11, min: 5, mean: 6.96
#  	conn counts: max: 11, min: 0, mean: 5.32
#  	species: 15, [86, 4, 50, 44, 48, 52, 32, 41, 31, 18, 24, 25, 27, 5, 113]
#
# Generation: 47, Cost time: 8973.69ms
#  	fitness: valid cnt: 600, max: 256.7551, min: -267.0503, mean: 27.7983, std: 76.8241
#
# 	node counts: max: 11, min: 5, mean: 6.91
#  	conn counts: max: 11, min: 0, mean: 5.06
#  	species: 15, [42, 47, 72, 46, 38, 82, 42, 4, 26, 19, 26, 35, 3, 7, 111]
#
# Generation: 48, Cost time: 8940.85ms
#  	fitness: valid cnt: 600, max: 273.8542, min: -176.3546, mean: 29.4318, std: 75.7345
#
# 	node counts: max: 11, min: 5, mean: 6.91
#  	conn counts: max: 11, min: 0, mean: 5.00
#  	species: 15, [61, 46, 56, 61, 56, 28, 40, 49, 33, 30, 38, 7, 6, 9, 80]
#
# Generation: 49, Cost time: 8974.97ms
#  	fitness: valid cnt: 600, max: 263.9667, min: -178.1982, mean: 29.8929, std: 80.5155
#
# 	node counts: max: 11, min: 5, mean: 7.14
#  	conn counts: max: 12, min: 0, mean: 5.22
#  	species: 15, [63, 54, 49, 68, 48, 32, 2, 35, 30, 30, 27, 42, 12, 5, 103]
#
# Generation: 50, Cost time: 8942.85ms
#  	fitness: valid cnt: 600, max: 273.2101, min: -200.0436, mean: 27.2169, std: 80.1281
#
# 	node counts: max: 12, min: 5, mean: 7.18
#  	conn counts: max: 12, min: 0, mean: 5.33
#  	species: 15, [75, 59, 56, 58, 42, 43, 4, 33, 28, 29, 41, 8, 9, 3, 112]
#
# Generation: 51, Cost time: 8997.89ms
#  	fitness: valid cnt: 600, max: 242.8517, min: -163.4771, mean: 27.0637, std: 78.2579
#
# 	node counts: max: 12, min: 5, mean: 7.22
#  	conn counts: max: 14, min: 0, mean: 5.36
#  	species: 15, [59, 85, 9, 52, 58, 9, 36, 42, 28, 34, 16, 35, 9, 6, 122]
#
# Generation: 52, Cost time: 8968.70ms
#  	fitness: valid cnt: 600, max: 260.0721, min: -314.0093, mean: 30.1880, std: 79.2492
#
# 	node counts: max: 12, min: 5, mean: 7.47
#  	conn counts: max: 13, min: 0, mean: 5.89
#  	species: 15, [76, 39, 3, 66, 57, 44, 36, 40, 30, 28, 15, 12, 8, 8, 138]
#
# Generation: 53, Cost time: 9001.14ms
#  	fitness: valid cnt: 600, max: 255.9314, min: -206.1162, mean: 27.3226, std: 78.7194
#
# 	node counts: max: 12, min: 5, mean: 7.49
#  	conn counts: max: 13, min: 0, mean: 5.77
#  	species: 15, [66, 44, 50, 39, 40, 5, 49, 32, 31, 29, 27, 11, 11, 3, 163]
#
# Generation: 54, Cost time: 8967.18ms
#  	fitness: valid cnt: 600, max: 250.9576, min: -136.6461, mean: 31.0465, std: 76.4407
#
# 	node counts: max: 13, min: 5, mean: 7.51
#  	conn counts: max: 14, min: 0, mean: 5.97
#  	species: 15, [71, 26, 51, 44, 74, 57, 2, 31, 26, 32, 22, 12, 11, 4, 137]
#
# Generation: 55, Cost time: 9027.62ms
#  	fitness: valid cnt: 600, max: 266.0026, min: -265.4904, mean: 27.3073, std: 83.8754
#
# 	node counts: max: 13, min: 5, mean: 7.70
#  	conn counts: max: 14, min: 0, mean: 6.07
#  	species: 15, [70, 42, 55, 34, 14, 46, 50, 44, 26, 41, 24, 11, 4, 8, 131]
#
# Generation: 56, Cost time: 8992.10ms
#  	fitness: valid cnt: 600, max: 259.3548, min: -180.6564, mean: 31.2073, std: 79.3519
#
# 	node counts: max: 13, min: 5, mean: 7.87
#  	conn counts: max: 14, min: 0, mean: 6.45
#  	species: 15, [77, 59, 55, 4, 12, 78, 31, 12, 39, 36, 23, 9, 29, 5, 131]
#
# Generation: 57, Cost time: 9026.85ms
#  	fitness: valid cnt: 600, max: 265.6380, min: -160.8570, mean: 32.6437, std: 83.0962
#
# 	node counts: max: 14, min: 5, mean: 7.95
#  	conn counts: max: 16, min: 0, mean: 6.22
#  	species: 15, [84, 49, 72, 1, 51, 2, 32, 37, 19, 17, 31, 16, 8, 36, 145]
#
# Generation: 58, Cost time: 9023.62ms
#  	fitness: valid cnt: 600, max: 268.2032, min: -181.5195, mean: 21.3540, std: 71.8608
#
# 	node counts: max: 14, min: 5, mean: 7.44
#  	conn counts: max: 15, min: 0, mean: 5.45
#  	species: 15, [81, 53, 50, 1, 65, 42, 34, 1, 23, 44, 19, 17, 11, 5, 154]
#
# Generation: 59, Cost time: 9050.99ms
#  	fitness: valid cnt: 600, max: 256.8120, min: -264.7816, mean: 20.4557, std: 72.1292
#
# 	node counts: max: 14, min: 5, mean: 7.25
#  	conn counts: max: 15, min: 0, mean: 5.10
#  	species: 15, [92, 47, 48, 59, 2, 47, 35, 39, 29, 15, 14, 45, 16, 12, 100]
#
# Generation: 60, Cost time: 9024.79ms
#  	fitness: valid cnt: 600, max: 253.6475, min: -167.5678, mean: 25.7233, std: 76.6690
#
# 	node counts: max: 14, min: 5, mean: 7.64
#  	conn counts: max: 16, min: 0, mean: 5.64
#  	species: 15, [71, 48, 53, 45, 3, 40, 60, 37, 12, 34, 18, 46, 15, 7, 111]
#
# Generation: 61, Cost time: 9091.13ms
#  	fitness: valid cnt: 600, max: 262.2108, min: -187.3606, mean: 23.2420, std: 77.6127
#
# 	node counts: max: 15, min: 5, mean: 7.71
#  	conn counts: max: 16, min: 0, mean: 5.85
#  	species: 15, [76, 4, 43, 49, 59, 39, 41, 56, 20, 31, 13, 15, 33, 8, 113]
#
# Generation: 62, Cost time: 9080.37ms
#  	fitness: valid cnt: 600, max: 274.9150, min: -166.2898, mean: 28.3799, std: 75.6511
#
# 	node counts: max: 15, min: 5, mean: 7.76
#  	conn counts: max: 16, min: 0, mean: 6.23
#  	species: 15, [63, 74, 45, 46, 59, 46, 2, 38, 21, 29, 39, 16, 9, 8, 105]
#
# Generation: 63, Cost time: 9115.34ms
#  	fitness: valid cnt: 600, max: 275.8058, min: -279.7126, mean: 24.9462, std: 81.7650
#
# 	node counts: max: 16, min: 5, mean: 7.70
#  	conn counts: max: 17, min: 0, mean: 6.14
#  	species: 15, [88, 62, 40, 66, 12, 7, 27, 32, 35, 34, 18, 12, 36, 10, 121]
#
# Generation: 64, Cost time: 9105.04ms
#  	fitness: valid cnt: 600, max: 268.0229, min: -178.8017, mean: 23.1945, std: 77.9907
#
# 	node counts: max: 16, min: 5, mean: 7.91
#  	conn counts: max: 18, min: 0, mean: 6.58
#  	species: 15, [57, 65, 2, 62, 42, 69, 27, 35, 17, 9, 27, 21, 33, 11, 123]
#
# Generation: 65, Cost time: 9139.92ms
#  	fitness: valid cnt: 600, max: 273.4217, min: -149.5615, mean: 29.6408, std: 78.3522
#
# 	node counts: max: 16, min: 5, mean: 7.87
#  	conn counts: max: 18, min: 0, mean: 6.77
#  	species: 15, [61, 64, 50, 49, 43, 56, 37, 26, 11, 12, 31, 19, 25, 3, 113]
#
# Generation: 66, Cost time: 9107.06ms
#  	fitness: valid cnt: 600, max: 266.9820, min: -200.9270, mean: 26.7597, std: 81.5794
#
# 	node counts: max: 16, min: 5, mean: 7.89
#  	conn counts: max: 17, min: 0, mean: 7.04
#  	species: 15, [91, 51, 63, 1, 60, 38, 37, 40, 18, 16, 34, 22, 24, 3, 102]
#
# Generation: 67, Cost time: 9137.50ms
#  	fitness: valid cnt: 600, max: 261.6364, min: -165.2048, mean: 28.6388, std: 83.6522
#
# 	node counts: max: 16, min: 5, mean: 7.57
#  	conn counts: max: 17, min: 0, mean: 6.56
#  	species: 15, [6, 42, 57, 32, 31, 53, 64, 37, 37, 46, 33, 21, 21, 6, 114]
#
# Generation: 68, Cost time: 9098.09ms
#  	fitness: valid cnt: 600, max: 262.7190, min: -185.4333, mean: 28.7031, std: 81.8672
#
# 	node counts: max: 15, min: 5, mean: 7.54
#  	conn counts: max: 17, min: 0, mean: 6.39
#  	species: 15, [59, 53, 64, 55, 56, 51, 37, 8, 10, 29, 30, 24, 11, 10, 103]
#
# Generation: 69, Cost time: 9105.57ms
#  	fitness: valid cnt: 600, max: 268.0910, min: -175.7437, mean: 29.2905, std: 82.4003
#
# 	node counts: max: 16, min: 5, mean: 7.83
#  	conn counts: max: 15, min: 0, mean: 6.91
#  	species: 15, [8, 61, 65, 4, 97, 54, 47, 46, 29, 4, 25, 17, 7, 7, 129]
#
# Generation: 70, Cost time: 9069.40ms
#  	fitness: valid cnt: 600, max: 260.9415, min: -153.4285, mean: 32.0357, std: 83.9516
#
# 	node counts: max: 13, min: 5, mean: 7.45
#  	conn counts: max: 15, min: 0, mean: 6.31
#  	species: 15, [76, 57, 59, 77, 31, 10, 44, 16, 38, 26, 22, 20, 14, 9, 101]
#
# Generation: 71, Cost time: 9025.23ms
#  	fitness: valid cnt: 600, max: 263.0170, min: -320.1251, mean: 25.0719, std: 82.9334
#
# 	node counts: max: 13, min: 5, mean: 7.33
#  	conn counts: max: 15, min: 0, mean: 6.52
#  	species: 15, [123, 62, 52, 30, 36, 43, 34, 66, 27, 31, 19, 10, 24, 11, 32]
#
# Generation: 72, Cost time: 8993.05ms
#  	fitness: valid cnt: 600, max: 270.5116, min: -165.5183, mean: 21.1579, std: 78.3573
#
# 	node counts: max: 13, min: 5, mean: 7.54
#  	conn counts: max: 16, min: 0, mean: 6.53
#  	species: 15, [74, 76, 55, 47, 43, 43, 38, 74, 5, 22, 22, 11, 20, 19, 51]
#
# Generation: 73, Cost time: 9024.18ms
#  	fitness: valid cnt: 600, max: 266.5432, min: -207.3809, mean: 28.4757, std: 81.1272
#
# 	node counts: max: 14, min: 5, mean: 7.44
#  	conn counts: max: 17, min: 0, mean: 6.21
#  	species: 15, [46, 80, 44, 40, 34, 9, 45, 41, 53, 57, 26, 13, 14, 24, 74]
#
# Generation: 74, Cost time: 9012.67ms
#  	fitness: valid cnt: 600, max: 274.0732, min: -193.1626, mean: 32.1861, std: 78.8395
#
# 	node counts: max: 13, min: 5, mean: 7.52
#  	conn counts: max: 17, min: 0, mean: 6.39
#  	species: 15, [86, 50, 37, 53, 49, 50, 47, 39, 27, 28, 9, 27, 13, 3, 82]
#
# Generation: 75, Cost time: 9035.36ms
#  	fitness: valid cnt: 600, max: 273.5598, min: -168.5941, mean: 33.9680, std: 79.4099
#
# 	node counts: max: 14, min: 5, mean: 7.38
#  	conn counts: max: 17, min: 0, mean: 6.20
#  	species: 15, [61, 34, 56, 51, 43, 38, 53, 30, 42, 29, 20, 13, 30, 18, 82]
#
# Generation: 76, Cost time: 9187.55ms
#  	fitness: valid cnt: 600, max: 265.7246, min: -151.7574, mean: 26.6225, std: 80.1977
#
# 	node counts: max: 14, min: 5, mean: 7.34
#  	conn counts: max: 17, min: 0, mean: 6.29
#  	species: 15, [71, 57, 60, 41, 52, 9, 39, 37, 32, 33, 33, 22, 13, 26, 75]
#
# Generation: 77, Cost time: 9269.37ms
#  	fitness: valid cnt: 600, max: 259.7076, min: -169.7546, mean: 32.5320, std: 81.4672
#
# 	node counts: max: 13, min: 5, mean: 7.32
#  	conn counts: max: 16, min: 0, mean: 6.07
#  	species: 15, [56, 68, 54, 53, 36, 20, 40, 49, 39, 4, 29, 18, 14, 25, 95]
#
# Generation: 78, Cost time: 8980.58ms
#  	fitness: valid cnt: 600, max: 267.3619, min: -148.1576, mean: 31.0077, std: 79.3136
#
# 	node counts: max: 14, min: 5, mean: 7.44
#  	conn counts: max: 18, min: 0, mean: 6.32
#  	species: 15, [86, 57, 34, 6, 43, 49, 49, 43, 48, 22, 28, 15, 21, 4, 95]
#
# Generation: 79, Cost time: 9119.13ms
#  	fitness: valid cnt: 600, max: 273.3065, min: -159.7042, mean: 30.1247, std: 81.9243
#
# 	node counts: max: 14, min: 5, mean: 7.42
#  	conn counts: max: 17, min: 0, mean: 6.53
#  	species: 15, [117, 61, 61, 53, 37, 2, 44, 29, 21, 29, 9, 20, 20, 9, 88]
#
# Generation: 80, Cost time: 8857.37ms
#  	fitness: valid cnt: 600, max: 263.9868, min: -197.4772, mean: 25.5517, std: 82.5787
#
# 	node counts: max: 14, min: 5, mean: 7.54
#  	conn counts: max: 16, min: 0, mean: 6.55
#  	species: 15, [134, 69, 59, 52, 55, 5, 26, 33, 32, 21, 17, 22, 15, 7, 53]
#
# Generation: 81, Cost time: 9164.11ms
#  	fitness: valid cnt: 600, max: 260.5496, min: -183.1573, mean: 27.3020, std: 85.5202
#
# 	node counts: max: 14, min: 5, mean: 7.58
#  	conn counts: max: 17, min: 0, mean: 6.44
#  	species: 15, [68, 100, 48, 56, 40, 38, 37, 26, 19, 17, 18, 23, 21, 8, 81]
#
# Generation: 82, Cost time: 9016.37ms
#  	fitness: valid cnt: 600, max: 271.7237, min: -156.9222, mean: 27.4385, std: 80.0770
#
# 	node counts: max: 15, min: 5, mean: 7.73
#  	conn counts: max: 18, min: 0, mean: 6.63
#  	species: 15, [70, 80, 47, 56, 26, 31, 32, 34, 48, 29, 15, 23, 3, 10, 96]
#
# Generation: 83, Cost time: 8977.32ms
#  	fitness: valid cnt: 600, max: 261.8969, min: -192.6815, mean: 25.7502, std: 76.7717
#
# 	node counts: max: 16, min: 5, mean: 7.93
#  	conn counts: max: 18, min: 0, mean: 6.83
#  	species: 15, [57, 74, 66, 56, 45, 36, 36, 31, 33, 16, 25, 27, 2, 6, 90]
#
# Generation: 84, Cost time: 8893.37ms
#  	fitness: valid cnt: 600, max: 260.6022, min: -207.7488, mean: 33.6325, std: 84.5197
#
# 	node counts: max: 17, min: 5, mean: 8.27
#  	conn counts: max: 18, min: 0, mean: 7.12
#  	species: 15, [71, 72, 16, 64, 44, 34, 38, 16, 29, 34, 24, 24, 24, 7, 103]
#
# Generation: 85, Cost time: 8957.89ms
#  	fitness: valid cnt: 600, max: 296.3169, min: -189.5007, mean: 36.3115, std: 83.6494
#
# 	node counts: max: 16, min: 5, mean: 8.28
#  	conn counts: max: 18, min: 0, mean: 7.04
#  	species: 15, [81, 70, 66, 1, 32, 46, 33, 31, 30, 30, 21, 19, 17, 17, 106]
#
# Generation: 86, Cost time: 8924.22ms
#  	fitness: valid cnt: 600, max: 266.5498, min: -168.3831, mean: 36.3754, std: 86.6785
#
# 	node counts: max: 16, min: 5, mean: 7.93
#  	conn counts: max: 19, min: 0, mean: 6.67
#  	species: 15, [61, 68, 62, 45, 65, 39, 23, 29, 30, 1, 27, 20, 16, 22, 92]
#
# Generation: 87, Cost time: 9124.18ms
#  	fitness: valid cnt: 600, max: 288.1197, min: -192.8419, mean: 32.8473, std: 84.3710
#
# 	node counts: max: 15, min: 5, mean: 7.71
#  	conn counts: max: 15, min: 0, mean: 6.28
#  	species: 15, [68, 71, 50, 35, 57, 52, 39, 2, 28, 28, 24, 17, 15, 28, 86]
#
# Generation: 88, Cost time: 8985.25ms
#  	fitness: valid cnt: 600, max: 284.7209, min: -203.3313, mean: 39.5228, std: 86.7459
#
# 	node counts: max: 15, min: 5, mean: 7.88
#  	conn counts: max: 15, min: 0, mean: 6.53
#  	species: 15, [93, 61, 59, 40, 67, 46, 31, 1, 32, 36, 19, 13, 22, 1, 79]
#
# Generation: 89, Cost time: 8986.02ms
#  	fitness: valid cnt: 600, max: 244.3388, min: -143.5322, mean: 31.3087, std: 78.8467
#
# 	node counts: max: 15, min: 5, mean: 8.06
#  	conn counts: max: 15, min: 0, mean: 6.85
#  	species: 15, [109, 58, 4, 63, 68, 44, 63, 28, 31, 30, 7, 3, 3, 1, 88]
#
# Generation: 90, Cost time: 8923.31ms
#  	fitness: valid cnt: 600, max: 257.6487, min: -224.2000, mean: 27.0903, std: 82.7036
#
# 	node counts: max: 16, min: 5, mean: 7.83
#  	conn counts: max: 14, min: 0, mean: 6.21
#  	species: 15, [113, 3, 58, 85, 58, 53, 41, 35, 11, 14, 17, 8, 5, 36, 63]
#
# Generation: 91, Cost time: 8965.55ms
#  	fitness: valid cnt: 600, max: 270.1333, min: -176.8316, mean: 27.6664, std: 80.1630
#
# 	node counts: max: 15, min: 5, mean: 7.97
#  	conn counts: max: 13, min: 0, mean: 5.91
#  	species: 15, [62, 92, 57, 69, 50, 48, 41, 33, 45, 21, 13, 13, 17, 9, 30]
#
# Generation: 92, Cost time: 8984.81ms
#  	fitness: valid cnt: 600, max: 287.4031, min: -189.8113, mean: 28.8873, std: 80.0144
#
# 	node counts: max: 15, min: 5, mean: 8.04
#  	conn counts: max: 13, min: 0, mean: 5.87
#  	species: 15, [87, 62, 63, 57, 42, 40, 48, 39, 3, 20, 14, 37, 16, 11, 61]
#
# Generation: 93, Cost time: 9036.63ms
#  	fitness: valid cnt: 600, max: 280.1418, min: -148.9133, mean: 28.6521, std: 80.5350
#
# 	node counts: max: 16, min: 5, mean: 8.28
#  	conn counts: max: 13, min: 0, mean: 6.11
#  	species: 15, [66, 56, 80, 53, 44, 41, 53, 32, 2, 26, 36, 4, 14, 14, 79]
#
# Generation: 94, Cost time: 8972.03ms
#  	fitness: valid cnt: 600, max: 292.1837, min: -181.0379, mean: 31.8417, std: 82.3735
#
# 	node counts: max: 16, min: 5, mean: 8.61
#  	conn counts: max: 14, min: 0, mean: 6.71
#  	species: 15, [81, 56, 86, 57, 43, 31, 4, 92, 2, 27, 11, 13, 13, 4, 80]
#
# Generation: 95, Cost time: 8950.07ms
#  	fitness: valid cnt: 600, max: 273.4515, min: -191.5118, mean: 31.6100, std: 81.5098
#
# 	node counts: max: 16, min: 5, mean: 8.87
#  	conn counts: max: 15, min: 0, mean: 7.11
#  	species: 15, [59, 60, 67, 77, 29, 47, 33, 27, 12, 17, 20, 8, 1, 12, 131]
#
# Generation: 96, Cost time: 8933.27ms
#  	fitness: valid cnt: 600, max: 269.9558, min: -182.2258, mean: 34.7604, std: 85.9786
#
# 	node counts: max: 17, min: 5, mean: 9.01
#  	conn counts: max: 15, min: 0, mean: 7.16
#  	species: 15, [75, 66, 55, 59, 43, 1, 39, 28, 18, 23, 21, 14, 16, 11, 131]
#
# Generation: 97, Cost time: 9065.12ms
#  	fitness: valid cnt: 600, max: 299.2326, min: -231.8093, mean: 30.3948, std: 83.2367
#
# 	node counts: max: 16, min: 5, mean: 8.99
#  	conn counts: max: 16, min: 0, mean: 7.26
#  	species: 15, [67, 69, 59, 45, 56, 36, 48, 15, 1, 1, 25, 13, 15, 10, 140]
#
# Generation: 98, Cost time: 9125.36ms
#  	fitness: valid cnt: 600, max: 288.8065, min: -225.7055, mean: 27.3713, std: 83.7349
#
# 	node counts: max: 17, min: 5, mean: 8.83
#  	conn counts: max: 16, min: 0, mean: 7.32
#  	species: 15, [68, 62, 57, 68, 45, 44, 38, 2, 25, 24, 9, 14, 12, 9, 123]
#
# Generation: 99, Cost time: 9033.92ms
#  	fitness: valid cnt: 600, max: 269.6091, min: -216.8859, mean: 30.4306, std: 82.0732
#
# 	node counts: max: 16, min: 5, mean: 9.01
#  	conn counts: max: 17, min: 0, mean: 7.62
#  	species: 15, [65, 60, 61, 54, 73, 5, 35, 39, 36, 3, 20, 20, 7, 12, 110]
#
# Generation: 100, Cost time: 9108.79ms
#  	fitness: valid cnt: 600, max: 278.9675, min: -219.5895, mean: 32.2714, std: 83.3324
#
# 	node counts: max: 16, min: 5, mean: 8.94
#  	conn counts: max: 17, min: 0, mean: 7.47
#  	species: 15, [80, 59, 58, 54, 52, 40, 1, 32, 37, 23, 24, 10, 10, 2, 118]
#
# Generation: 101, Cost time: 8950.08ms
#  	fitness: valid cnt: 600, max: 261.7297, min: -229.6406, mean: 35.4912, std: 83.0303
#
# 	node counts: max: 16, min: 5, mean: 9.02
#  	conn counts: max: 17, min: 0, mean: 7.44
#  	species: 15, [91, 43, 60, 77, 2, 45, 3, 38, 28, 23, 7, 15, 7, 46, 115]
#
# Generation: 102, Cost time: 8964.09ms
#  	fitness: valid cnt: 600, max: 279.7705, min: -163.8149, mean: 35.0287, std: 80.9152
#
# 	node counts: max: 17, min: 5, mean: 8.95
#  	conn counts: max: 19, min: 0, mean: 7.65
#  	species: 15, [81, 81, 70, 43, 10, 44, 45, 38, 29, 15, 16, 9, 2, 8, 109]
#
# Generation: 103, Cost time: 9160.64ms
#  	fitness: valid cnt: 600, max: 288.9985, min: -163.5181, mean: 34.1701, std: 81.8701
#
# 	node counts: max: 16, min: 5, mean: 8.90
#  	conn counts: max: 17, min: 0, mean: 7.48
#  	species: 15, [73, 61, 62, 64, 19, 47, 5, 42, 24, 30, 13, 21, 14, 3, 122]
#
# Generation: 104, Cost time: 9119.43ms
#  	fitness: valid cnt: 600, max: 305.2614, min: -194.4735, mean: 31.9537, std: 85.0775
#
# 	node counts: max: 17, min: 5, mean: 8.98
#  	conn counts: max: 17, min: 0, mean: 7.49
#  	species: 15, [76, 68, 29, 57, 48, 33, 28, 48, 41, 29, 4, 13, 9, 6, 111]
#
# Generation: 105, Cost time: 9176.46ms
#  	fitness: valid cnt: 600, max: 285.8283, min: -271.8938, mean: 28.3820, std: 83.2132
#
# 	node counts: max: 18, min: 5, mean: 9.16
#  	conn counts: max: 16, min: 0, mean: 7.91
#  	species: 15, [93, 60, 42, 3, 50, 50, 45, 39, 34, 17, 15, 10, 19, 6, 117]
#
# Generation: 106, Cost time: 8954.74ms
#  	fitness: valid cnt: 600, max: 294.6097, min: -165.9233, mean: 30.7389, std: 80.3944
#
# 	node counts: max: 18, min: 5, mean: 9.01
#  	conn counts: max: 16, min: 0, mean: 7.57
#  	species: 15, [81, 64, 50, 50, 42, 47, 2, 37, 36, 21, 20, 14, 20, 9, 107]
#
# Generation: 107, Cost time: 9027.80ms
#  	fitness: valid cnt: 600, max: 281.2123, min: -205.5503, mean: 31.7199, std: 81.7927
#
# 	node counts: max: 18, min: 5, mean: 9.02
#  	conn counts: max: 17, min: 0, mean: 7.57
#  	species: 15, [78, 58, 53, 79, 45, 6, 2, 33, 41, 8, 13, 23, 15, 9, 137]
#
# Generation: 108, Cost time: 9152.33ms
#  	fitness: valid cnt: 600, max: 288.3198, min: -238.8978, mean: 31.9818, std: 83.1543
#
# 	node counts: max: 18, min: 5, mean: 9.23
#  	conn counts: max: 17, min: 0, mean: 7.98
#  	species: 15, [94, 62, 51, 39, 46, 15, 32, 44, 2, 22, 1, 13, 14, 7, 158]
#
# Generation: 109, Cost time: 9129.86ms
#  	fitness: valid cnt: 600, max: 282.0957, min: -157.1830, mean: 38.7758, std: 80.7996
#
# 	node counts: max: 17, min: 5, mean: 8.67
#  	conn counts: max: 18, min: 0, mean: 7.18
#  	species: 15, [63, 35, 57, 42, 73, 44, 44, 32, 11, 18, 19, 16, 5, 5, 136]
#
# Generation: 110, Cost time: 9078.07ms
#  	fitness: valid cnt: 600, max: 264.2313, min: -197.6754, mean: 23.7592, std: 79.8763
#
# 	node counts: max: 17, min: 5, mean: 8.88
#  	conn counts: max: 18, min: 0, mean: 7.46
#  	species: 15, [110, 44, 57, 49, 45, 35, 37, 4, 4, 21, 12, 15, 30, 14, 123]
#
# Generation: 111, Cost time: 9066.39ms
#  	fitness: valid cnt: 600, max: 279.7386, min: -178.4687, mean: 32.2343, std: 80.9591
#
# 	node counts: max: 17, min: 5, mean: 9.04
#  	conn counts: max: 19, min: 0, mean: 7.37
#  	species: 15, [100, 52, 56, 45, 23, 35, 47, 28, 44, 14, 14, 14, 6, 5, 117]
#
# Generation: 112, Cost time: 9086.48ms
#  	fitness: valid cnt: 600, max: 274.0872, min: -177.0138, mean: 30.8268, std: 78.2225
#
# 	node counts: max: 18, min: 5, mean: 8.97
#  	conn counts: max: 18, min: 0, mean: 7.54
#  	species: 15, [66, 67, 36, 48, 46, 20, 47, 54, 6, 24, 5, 15, 14, 12, 140]
#
# Generation: 113, Cost time: 9129.57ms
#  	fitness: valid cnt: 600, max: 271.7197, min: -156.2475, mean: 32.2221, std: 79.3245
#
# 	node counts: max: 18, min: 5, mean: 9.34
#  	conn counts: max: 19, min: 0, mean: 8.14
#  	species: 15, [64, 69, 16, 53, 42, 52, 43, 27, 28, 16, 15, 14, 11, 1, 149]
#
# Generation: 114, Cost time: 9091.77ms
#  	fitness: valid cnt: 600, max: 272.9973, min: -160.1628, mean: 33.2929, std: 80.6702
#
# 	node counts: max: 18, min: 5, mean: 9.44
#  	conn counts: max: 19, min: 0, mean: 8.06
#  	species: 15, [55, 60, 58, 35, 45, 1, 64, 25, 1, 58, 14, 15, 22, 9, 138]
#
# Generation: 115, Cost time: 9251.45ms
#  	fitness: valid cnt: 600, max: 300.6284, min: -221.6285, mean: 35.6232, std: 83.2628
#
# 	node counts: max: 18, min: 5, mean: 9.05
#  	conn counts: max: 19, min: 0, mean: 7.74
#  	species: 15, [71, 72, 55, 56, 33, 48, 57, 1, 46, 10, 11, 28, 9, 2, 101]
#
# Generation: 116, Cost time: 9158.20ms
#  	fitness: valid cnt: 600, max: 284.9778, min: -143.8282, mean: 34.6638, std: 82.5567
#
# 	node counts: max: 18, min: 5, mean: 8.91
#  	conn counts: max: 18, min: 0, mean: 7.49
#  	species: 15, [64, 68, 63, 53, 50, 50, 31, 44, 4, 1, 14, 8, 27, 11, 112]
#
# Generation: 117, Cost time: 9167.53ms
#  	fitness: valid cnt: 600, max: 299.2156, min: -256.0692, mean: 37.1114, std: 85.5158
#
# 	node counts: max: 18, min: 5, mean: 8.87
#  	conn counts: max: 16, min: 0, mean: 7.60
#  	species: 15, [70, 60, 66, 51, 35, 26, 9, 42, 44, 21, 16, 23, 12, 9, 116]
#
# Generation: 118, Cost time: 9025.84ms
#  	fitness: valid cnt: 600, max: 299.5200, min: -177.1387, mean: 31.5562, std: 80.2648
#
# 	node counts: max: 18, min: 5, mean: 8.99
#  	conn counts: max: 17, min: 0, mean: 7.72
#  	species: 15, [78, 54, 62, 57, 3, 45, 43, 42, 27, 4, 17, 12, 18, 10, 128]
#
# Generation: 119, Cost time: 9215.55ms
#  	fitness: valid cnt: 600, max: 288.1528, min: -177.4601, mean: 33.0868, std: 83.3569
#
# 	node counts: max: 18, min: 5, mean: 9.10
#  	conn counts: max: 18, min: 0, mean: 7.95
#  	species: 15, [72, 60, 60, 55, 50, 7, 43, 41, 5, 26, 19, 20, 9, 6, 127]
#
# Generation: 120, Cost time: 9119.62ms
#  	fitness: valid cnt: 600, max: 283.9899, min: -197.6680, mean: 28.6474, std: 78.4473
#
# 	node counts: max: 18, min: 5, mean: 9.11
#  	conn counts: max: 18, min: 0, mean: 8.15
#  	species: 15, [101, 62, 64, 17, 81, 47, 8, 5, 41, 19, 14, 14, 10, 8, 109]
#
# Generation: 121, Cost time: 9120.07ms
#  	fitness: valid cnt: 600, max: 282.5226, min: -240.7439, mean: 25.5669, std: 79.7344
#
# 	node counts: max: 18, min: 5, mean: 9.40
#  	conn counts: max: 18, min: 0, mean: 8.58
#  	species: 15, [88, 86, 53, 39, 53, 28, 41, 7, 21, 16, 21, 18, 29, 4, 96]
#
# Generation: 122, Cost time: 9233.41ms
#  	fitness: valid cnt: 600, max: 305.9008, min: -180.1641, mean: 30.8307, std: 86.6701
#
# 	node counts: max: 19, min: 5, mean: 9.39
#  	conn counts: max: 19, min: 0, mean: 8.44
#  	species: 15, [52, 74, 33, 45, 22, 40, 49, 54, 1, 21, 5, 61, 21, 14, 108]
