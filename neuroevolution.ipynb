# %% [markdown]
# # Problem-Specific Coordinate Generation for HyperNEAT Substrates
#
# # Part 3: Neuroevolution
#
# In this part, the created substrates are tested on the defined problem.

# %% [markdown]
# ## Setup
#
# ### Imports

# %%
import os
import pickle
from collections import defaultdict

import wandb

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from config import config

import jax
from tensorneat.common import State

from evol_pipeline.brax_env import CustomBraxEnv
from evol_pipeline.custom_pipeline import CustomPipeline
from evol_pipeline.evol_algorithm import create_evol_algorithm

from utils.visualization import visualize_cppn, visualize_nn
from utils.utils import setup_folders_evolution, append_summary_row

# %% [markdown]
# The folder structure is checked and setup if necessary. A deep dictionary is defined and will hold the different substrates.

# %%
OUTPUT_DIR = config["experiment"]["output_dir_evolultion"]
setup_folders_evolution(OUTPUT_DIR)

def deep_defaultdict():
    return defaultdict(deep_defaultdict)

# %% [markdown]
# ### Setup Environment
#
# [Brax environments](https://github.com/google/brax/tree/main/brax/envs) are used for this experiment through the [TensorNEAT wrapper](https://github.com/EMI-Group/tensorneat/tree/main/src/tensorneat/problem/rl).

# %%
env_name = config["experiment"]["env_name"]
env_problem = CustomBraxEnv(
    env_name=env_name,
    backend=config["environment"]["backend"],
    brax_args=config["environment"]["brax_args"],
    max_step=config["environment"]["max_step"],
    repeat_times=config["environment"]["repeat_times"],
    obs_normalization=config["environment"]["obs_normalization"],
    sample_episodes=config["environment"]["sample_episodes"],
)
obs_size = env_problem.input_shape[0]
act_size = env_problem.output_shape[0]
# Out:
# /home/andi/anaconda3/envs/jax/lib/python3.10/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# 2025-11-03 10:33:29.188280: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-03 10:33:39.948119: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.

# %% [markdown]
# The substrates which were previously saved to disk are used for the neuroevolution process.

# %%
with open(config["experiment"]["substrates_path"], "rb") as f:
    substrates = pickle.load(f)

# %% [markdown]
# ## Neuroevolution
#
# Finally the substrates are ready to be used for neuroevolution with HyperNEAT. Weights and Biases (wandb) is used for logging and the CPPNs with highest fitness and their phenotypes are visualized. Coordinates are logged for further analysis.

# %%
for data_label, data_dict in substrates.items():
    for method_label, method_dict in data_dict.items():
        for feature_dims_label, feature_dims_dict in method_dict.items():

            active_substrate = substrates[data_label][method_label][feature_dims_label]["substrate"]
            evol_algorithm = create_evol_algorithm(substrate=active_substrate)

            run_id = f"{data_label}_{method_label}_{substrate_dimensions}d"

            initial_cppn_layers = config["algorithm"]["genome"]["cppn_init_hidden_layers"](active_substrate.query_coors.shape[1])
            print("Intial CPPN Layers:", initial_cppn_layers)
            substrate_dimensions = int(active_substrate.query_coors.shape[1]/2)

            wanbd_name = run_id
            wandb_tags = [config["substrate"]["hidden_layer_type"], env_name, data_label, method_label, f"{config['substrate']['hidden_depth']}_hl", f"{config['algorithm']['neat']['pop_size']}pop", f"{config['environment']['backend']}"]

            wandb.init(
                name=wanbd_name,
                project="substrate_configuration",
                tags=wandb_tags,
                config=config  
            )

            wandb.config.update(
                {
                    "substrate": {
                        "obs_size": obs_size,
                        "act_size": act_size,
                        "num_queries": active_substrate.query_coors.shape[0],
                        "query_dim": active_substrate.query_coors.shape[1],
                        },
                    "algorithm": {
                        "neat": {
                            "num_inputs": evol_algorithm.num_inputs,
                            },
                        "genome": {
                            "cppn_init_hidden_layers": initial_cppn_layers,
                            },
                        },
                },
            )
            
            genome_save_dir = os.path.join(OUTPUT_DIR, "genome", run_id)
            os.makedirs(genome_save_dir, exist_ok=True)

            pipeline = CustomPipeline(
                algorithm=evol_algorithm,
                problem=env_problem,
                seed=config["experiment"]["seed"],
                generation_limit=config["pipeline"]["generation_limit"],
                fitness_target=config["pipeline"]["fitness_target"],
                is_save=True,
                save_dir=genome_save_dir,
            )

            init_state = pipeline.setup()
            train_state, best_genome = pipeline.auto_run(state=init_state)

            print(f"\nTraining finished. Best fitness achieved: {pipeline.best_fitness}")

            wandb.finish()

            append_summary_row(
                path=f"{OUTPUT_DIR}/summary_results.csv",
                row={
                    "dimensionality": int(active_substrate.query_coors.shape[1] / 2),
                    "sampling": data_label,
                    "method": method_label,
                    "max_fitness": float(pipeline.best_fitness),
                },
            )

            # A fresh state is used for the display with the show method
            showing_state = pipeline.setup()

            # Built-in show method to produce and save a video of the agent
            pipeline.show(
                state=showing_state,
                best=best_genome,
                output_type="mp4",
                save_path=f"{OUTPUT_DIR}/video/agent_{data_label}_{method_label}_{feature_dims_label}.mp4",
            )

            # All coordinates are needed for visualization
            input_coors = substrates[data_label][method_label][feature_dims_label]["input_coors"]
            hidden_coors = substrates[data_label][method_label][feature_dims_label]["hidden_coors"]
            output_coors = substrates[data_label][method_label][feature_dims_label]["output_coors"]

            # Visualizes the CPPN
            visualize_cppn(
                pipeline=pipeline, 
                state=train_state, 
                save_path=f"{OUTPUT_DIR}/topology/cppn_{data_label}_{method_label}_{feature_dims_label}.svg"
            )
            
            # Visualizes a representation of the neural network in 2D space
            visualize_nn(
                pipeline=pipeline, 
                state=train_state, 
                save_path=f"{OUTPUT_DIR}/topology/nn_{data_label}_{method_label}_{feature_dims_label}.svg", 
                substrate=active_substrate, 
                input_coors=input_coors, 
                hidden_coors=hidden_coors, 
                output_coors=output_coors, 
                hidden_depth=config["substrate"]["hidden_depth"], 
                max_weight=config["algorithm"]["hyperneat"]["max_weight"], 
            )
# Out:
# Intial CPPN Layers: [2]
# wandb: Currently logged in as: wirkelzirkel (wirkelzirkel-iu) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/andi/Dokumente/Bachelorarbeit/dim_tuning/wandb/run-20251103_103342-x0nk9rls</code>
# Syncing run <strong><a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/x0nk9rls' target="_blank">ant_manual_simple_2d</a></strong> to <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_configuration</a>
#  View run at <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/x0nk9rls' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/x0nk9rls</a>
# save to output/ant/genome/manual_simple_1fd
# initializing
# initializing finished
# start compile
# compile finished, cost time: 30.312680s
# Generation: 1, Cost time: 3345.22ms
#  	fitness: valid cnt: 300, max: 51.2546, min: -3955.9634, mean: -1384.1736, std: 1297.4559
#
# 	node counts: max: 8, min: 6, mean: 7.25
#  	conn counts: max: 12, min: 5, mean: 10.41
#  	species: 10, [24, 62, 23, 36, 10, 1, 1, 27, 1, 115]
#
# Generation: 2, Cost time: 3296.62ms
#  	fitness: valid cnt: 300, max: 51.4607, min: -3955.0356, mean: -515.2519, std: 1077.9319
#
# 	node counts: max: 9, min: 6, mean: 7.55
#  	conn counts: max: 14, min: 6, mean: 11.08
#  	species: 10, [36, 43, 35, 23, 30, 29, 10, 1, 9, 84]
#
# Generation: 3, Cost time: 3277.15ms
#  	fitness: valid cnt: 300, max: 52.0317, min: -3950.1392, mean: -166.3135, std: 721.0425
#
# 	node counts: max: 10, min: 6, mean: 7.82
#  	conn counts: max: 15, min: 5, mean: 11.55
#  	species: 10, [22, 1, 42, 24, 31, 25, 11, 23, 9, 112]
#
# Generation: 4, Cost time: 3291.17ms
#  	fitness: valid cnt: 300, max: 91.4007, min: -3947.4570, mean: -35.1383, std: 410.1804
#
# 	node counts: max: 10, min: 6, mean: 8.14
#  	conn counts: max: 16, min: 5, mean: 11.99
#  	species: 10, [1, 26, 40, 34, 26, 17, 8, 40, 10, 98]
#
# Generation: 5, Cost time: 3290.11ms
#  	fitness: valid cnt: 300, max: 115.3302, min: -3942.4133, mean: -95.5841, std: 524.7885
#
# 	node counts: max: 11, min: 6, mean: 8.41
#  	conn counts: max: 17, min: 5, mean: 12.25
#  	species: 10, [1, 31, 39, 27, 28, 15, 1, 13, 4, 141]
#
# Generation: 6, Cost time: 3282.08ms
#  	fitness: valid cnt: 300, max: 125.0803, min: -3949.1323, mean: -90.4178, std: 515.8932
#
# 	node counts: max: 11, min: 7, mean: 8.61
#  	conn counts: max: 16, min: 7, mean: 12.66
#  	species: 10, [2, 38, 1, 33, 30, 20, 17, 15, 9, 135]
#
# Generation: 7, Cost time: 3321.97ms
#  	fitness: valid cnt: 300, max: 113.8064, min: -2985.8552, mean: -91.7139, std: 428.6550
#
# 	node counts: max: 11, min: 7, mean: 8.69
#  	conn counts: max: 17, min: 8, mean: 13.08
#  	species: 10, [1, 43, 26, 24, 24, 21, 25, 10, 1, 125]
#
# Generation: 8, Cost time: 3331.43ms
#  	fitness: valid cnt: 300, max: 115.0404, min: -3820.0508, mean: -72.5128, std: 448.5793
#
# 	node counts: max: 11, min: 6, mean: 8.72
#  	conn counts: max: 17, min: 5, mean: 13.23
#  	species: 10, [2, 46, 34, 29, 27, 25, 10, 20, 7, 100]
#
# Generation: 9, Cost time: 3298.27ms
#  	fitness: valid cnt: 300, max: 107.5121, min: -3948.1306, mean: -174.9693, std: 650.2664
#
# 	node counts: max: 11, min: 7, mean: 9.05
#  	conn counts: max: 19, min: 8, mean: 13.88
#  	species: 10, [2, 46, 24, 29, 32, 9, 25, 21, 8, 104]
#
# Generation: 10, Cost time: 3323.06ms
#  	fitness: valid cnt: 300, max: 111.9354, min: -3475.8848, mean: -99.4808, std: 583.1827
#
# 	node counts: max: 11, min: 7, mean: 8.86
#  	conn counts: max: 19, min: 6, mean: 13.88
#  	species: 10, [1, 46, 20, 31, 28, 27, 26, 18, 5, 98]
#
# Generation: 11, Cost time: 3307.57ms
#  	fitness: valid cnt: 300, max: 122.3752, min: -3463.7141, mean: -73.4294, std: 448.7933
#
# 	node counts: max: 12, min: 6, mean: 9.12
#  	conn counts: max: 20, min: 6, mean: 14.07
#  	species: 10, [16, 37, 34, 28, 1, 27, 8, 17, 3, 129]
#
# Generation: 12, Cost time: 3288.32ms
#  	fitness: valid cnt: 300, max: 137.2100, min: -3666.7056, mean: -141.1529, std: 635.3193
#
# 	node counts: max: 13, min: 6, mean: 9.32
#  	conn counts: max: 22, min: 6, mean: 14.32
#  	species: 10, [1, 41, 25, 32, 17, 27, 27, 7, 7, 116]
#
# Generation: 13, Cost time: 3319.17ms
#  	fitness: valid cnt: 300, max: 137.5639, min: -3947.4529, mean: -185.3036, std: 673.1780
#
# 	node counts: max: 13, min: 7, mean: 9.62
#  	conn counts: max: 21, min: 8, mean: 15.01
#  	species: 10, [11, 45, 35, 31, 3, 29, 8, 6, 20, 112]
#
# Generation: 14, Cost time: 3300.00ms
#  	fitness: valid cnt: 300, max: 110.7838, min: -3949.3706, mean: -119.5499, std: 619.2852
#
# 	node counts: max: 13, min: 7, mean: 9.71
#  	conn counts: max: 22, min: 6, mean: 15.15
#  	species: 10, [1, 46, 38, 33, 30, 15, 1, 1, 16, 119]
#
# Generation: 15, Cost time: 3281.59ms
#  	fitness: valid cnt: 300, max: 123.8167, min: -3526.2690, mean: -112.3062, std: 555.5976
#
# 	node counts: max: 13, min: 7, mean: 9.77
#  	conn counts: max: 22, min: 7, mean: 15.07
#  	species: 10, [3, 47, 36, 35, 34, 19, 17, 9, 9, 91]
#
# Generation: 16, Cost time: 3306.07ms
#  	fitness: valid cnt: 300, max: 121.0375, min: -3475.6069, mean: -133.6726, std: 581.1421
#
# 	node counts: max: 13, min: 7, mean: 9.82
#  	conn counts: max: 23, min: 8, mean: 15.12
#  	species: 10, [18, 48, 31, 20, 33, 31, 1, 25, 18, 75]
#
# Generation: 17, Cost time: 3341.69ms
#  	fitness: valid cnt: 300, max: 108.9413, min: -3947.8672, mean: -161.7816, std: 674.1091
#
# 	node counts: max: 13, min: 8, mean: 10.14
#  	conn counts: max: 22, min: 10, mean: 15.46
#  	species: 10, [3, 43, 30, 35, 18, 26, 25, 24, 12, 84]
#
# Generation: 18, Cost time: 3321.08ms
#  	fitness: valid cnt: 300, max: 129.8208, min: -3834.2056, mean: -145.7913, std: 648.7584
#
# 	node counts: max: 13, min: 8, mean: 10.33
#  	conn counts: max: 22, min: 9, mean: 15.73
#  	species: 10, [1, 39, 39, 40, 29, 22, 21, 20, 11, 78]
#
# Generation: 19, Cost time: 3309.00ms
#  	fitness: valid cnt: 300, max: 121.4567, min: -3948.7349, mean: -115.4256, std: 601.0209
#
# 	node counts: max: 14, min: 8, mean: 10.39
#  	conn counts: max: 23, min: 11, mean: 15.87
#  	species: 10, [1, 44, 41, 39, 19, 24, 21, 9, 15, 87]
#
# Generation: 20, Cost time: 3311.04ms
#  	fitness: valid cnt: 300, max: 142.4734, min: -3467.4814, mean: -84.4879, std: 509.4378
#
# 	node counts: max: 14, min: 8, mean: 10.37
#  	conn counts: max: 23, min: 7, mean: 15.56
#  	species: 10, [1, 44, 43, 29, 19, 34, 22, 17, 12, 79]
#
# Generation: 21, Cost time: 3292.23ms
#  	fitness: valid cnt: 300, max: 126.3853, min: -3467.7454, mean: -178.1978, std: 687.3183
#
# 	node counts: max: 14, min: 7, mean: 10.55
#  	conn counts: max: 23, min: 7, mean: 15.91
#  	species: 10, [1, 46, 43, 36, 30, 19, 19, 19, 1, 86]
#
# Generation: 22, Cost time: 3296.42ms
#  	fitness: valid cnt: 300, max: 139.1189, min: -3950.8794, mean: -250.4599, std: 843.8272
#
# 	node counts: max: 14, min: 8, mean: 10.93
#  	conn counts: max: 23, min: 9, mean: 16.43
#  	species: 10, [2, 45, 42, 37, 31, 23, 20, 19, 9, 72]
#
# Generation: 23, Cost time: 3311.93ms
#  	fitness: valid cnt: 300, max: 130.0656, min: -3953.2139, mean: -200.9794, std: 751.9874
#
# 	node counts: max: 14, min: 8, mean: 11.22
#  	conn counts: max: 23, min: 9, mean: 17.24
#  	species: 10, [12, 47, 40, 37, 11, 23, 20, 19, 1, 90]
#
# Generation: 24, Cost time: 3303.88ms
#  	fitness: valid cnt: 300, max: 129.5110, min: -3946.9038, mean: -257.7712, std: 814.2971
#
# 	node counts: max: 15, min: 9, mean: 11.30
#  	conn counts: max: 25, min: 10, mean: 17.34
#  	species: 10, [1, 48, 41, 37, 21, 22, 17, 19, 14, 80]
#
# Generation: 25, Cost time: 3299.54ms
#  	fitness: valid cnt: 300, max: 110.6442, min: -3747.6611, mean: -134.1961, std: 573.8538
#
# 	node counts: max: 16, min: 9, mean: 11.52
#  	conn counts: max: 27, min: 11, mean: 18.01
#  	species: 10, [1, 48, 42, 37, 20, 21, 14, 17, 16, 84]
#
# Generation: 26, Cost time: 3347.49ms
#  	fitness: valid cnt: 300, max: 129.4623, min: -3951.5894, mean: -240.9925, std: 823.1874
#
# 	node counts: max: 17, min: 9, mean: 11.66
#  	conn counts: max: 29, min: 11, mean: 18.22
#  	species: 10, [1, 48, 39, 37, 18, 24, 18, 16, 3, 96]
#
# Generation: 27, Cost time: 3317.95ms
#  	fitness: valid cnt: 300, max: 113.8553, min: -3956.2634, mean: -140.5496, std: 608.2428
#
# 	node counts: max: 17, min: 9, mean: 11.92
#  	conn counts: max: 29, min: 9, mean: 18.93
#  	species: 10, [1, 48, 30, 15, 35, 25, 19, 10, 13, 104]
#
# Generation: 28, Cost time: 3280.57ms
#  	fitness: valid cnt: 300, max: 101.4404, min: -3750.7017, mean: -219.4791, std: 763.2108
#
# 	node counts: max: 17, min: 9, mean: 12.09
#  	conn counts: max: 29, min: 10, mean: 18.94
#  	species: 10, [64, 1, 40, 35, 24, 22, 8, 11, 9, 86]
#
# Generation: 29, Cost time: 3281.65ms
#  	fitness: valid cnt: 300, max: 101.9779, min: -3823.4150, mean: -183.1202, std: 668.9814
#
# 	node counts: max: 17, min: 9, mean: 12.16
#  	conn counts: max: 29, min: 9, mean: 19.22
#  	species: 9, [71, 69, 43, 37, 27, 18, 14, 12, 9]
#
# Generation: 30, Cost time: 3319.47ms
#  	fitness: valid cnt: 300, max: 129.3928, min: -3949.4185, mean: -243.0933, std: 842.2657
#
# 	node counts: max: 17, min: 8, mean: 12.50
#  	conn counts: max: 30, min: 10, mean: 20.13
#  	species: 10, [61, 62, 44, 38, 30, 22, 9, 12, 10, 12]
#
# Generation: 31, Cost time: 3388.91ms
#  	fitness: valid cnt: 300, max: 112.9228, min: -3959.6738, mean: -256.4843, std: 808.7054
#
# 	node counts: max: 15, min: 9, mean: 12.27
#  	conn counts: max: 26, min: 9, mean: 18.95
#  	species: 10, [7, 52, 45, 43, 20, 94, 9, 3, 8, 19]
#
# Generation: 32, Cost time: 3384.16ms
#  	fitness: valid cnt: 300, max: 110.1259, min: -3748.0435, mean: -314.2249, std: 880.8951
#
# 	node counts: max: 15, min: 10, mean: 12.71
#  	conn counts: max: 26, min: 11, mean: 19.80
#  	species: 10, [51, 64, 37, 45, 2, 34, 37, 1, 10, 19]
#
# Generation: 33, Cost time: 3374.95ms
#  	fitness: valid cnt: 300, max: 123.8056, min: -3953.3569, mean: -369.0001, std: 936.8911
#
# 	node counts: max: 15, min: 10, mean: 12.44
#  	conn counts: max: 26, min: 11, mean: 19.42
#  	species: 10, [61, 50, 44, 37, 15, 33, 10, 25, 14, 11]
#
# Generation: 34, Cost time: 3340.12ms
#  	fitness: valid cnt: 300, max: 112.5831, min: -3958.2949, mean: -308.0330, std: 852.7776
#
# 	node counts: max: 15, min: 9, mean: 12.75
#  	conn counts: max: 27, min: 10, mean: 19.82
#  	species: 10, [98, 8, 40, 40, 28, 30, 15, 15, 12, 14]
#
# Generation: 35, Cost time: 3377.20ms
#  	fitness: valid cnt: 300, max: 124.2389, min: -3945.7773, mean: -311.8293, std: 828.3582
#
# 	node counts: max: 15, min: 10, mean: 12.80
#  	conn counts: max: 28, min: 11, mean: 19.45
#  	species: 10, [64, 42, 41, 33, 30, 21, 18, 14, 1, 36]
#
# Generation: 36, Cost time: 3384.05ms
#  	fitness: valid cnt: 300, max: 136.0734, min: -3951.0374, mean: -249.3529, std: 812.2133
#
# 	node counts: max: 16, min: 10, mean: 12.81
#  	conn counts: max: 29, min: 11, mean: 20.01
#  	species: 9, [23, 47, 43, 36, 27, 28, 19, 13, 64]
#
# Generation: 37, Cost time: 3391.06ms
#  	fitness: valid cnt: 300, max: 122.5877, min: -3476.5718, mean: -230.8534, std: 744.4795
#
# 	node counts: max: 16, min: 10, mean: 13.03
#  	conn counts: max: 29, min: 12, mean: 20.47
#  	species: 10, [66, 50, 34, 40, 30, 26, 16, 16, 21, 1]
#
# Generation: 38, Cost time: 3395.13ms
#  	fitness: valid cnt: 300, max: 118.3862, min: -3635.0652, mean: -238.4841, std: 740.1044
#
# 	node counts: max: 17, min: 11, mean: 13.13
#  	conn counts: max: 30, min: 11, mean: 20.38
#  	species: 10, [42, 49, 54, 39, 29, 28, 18, 19, 13, 9]
#
# Generation: 39, Cost time: 3383.24ms
#  	fitness: valid cnt: 300, max: 137.1320, min: -3947.3267, mean: -263.9055, std: 793.2297
#
# 	node counts: max: 17, min: 11, mean: 13.58
#  	conn counts: max: 30, min: 12, mean: 21.41
#  	species: 10, [74, 47, 1, 39, 30, 22, 16, 15, 10, 46]
#
# Generation: 40, Cost time: 3273.07ms
#  	fitness: valid cnt: 300, max: 124.5149, min: -3910.8577, mean: -247.4268, std: 753.4474
#
# 	node counts: max: 17, min: 11, mean: 13.55
#  	conn counts: max: 31, min: 13, mean: 21.01
#  	species: 10, [55, 58, 40, 42, 15, 21, 21, 23, 13, 12]
#
# Generation: 41, Cost time: 3311.20ms
#  	fitness: valid cnt: 300, max: 115.3671, min: -3948.5420, mean: -285.7611, std: 813.6891
#
# 	node counts: max: 17, min: 11, mean: 13.60
#  	conn counts: max: 31, min: 13, mean: 20.92
#  	species: 10, [50, 49, 53, 40, 23, 24, 21, 14, 16, 10]
#
# Generation: 42, Cost time: 3230.00ms
#  	fitness: valid cnt: 300, max: 125.5382, min: -3469.3335, mean: -140.9673, std: 539.9484
#
# 	node counts: max: 18, min: 11, mean: 13.78
#  	conn counts: max: 31, min: 11, mean: 21.07
#  	species: 10, [55, 56, 40, 39, 27, 24, 22, 13, 13, 11]
#
# Generation: 43, Cost time: 3226.79ms
#  	fitness: valid cnt: 300, max: 113.8131, min: -3947.7800, mean: -275.3538, std: 844.3282
#
# 	node counts: max: 18, min: 11, mean: 13.70
#  	conn counts: max: 31, min: 15, mean: 21.06
#  	species: 10, [59, 51, 41, 38, 29, 25, 21, 14, 11, 11]
#
# Generation: 44, Cost time: 3245.29ms
#  	fitness: valid cnt: 300, max: 131.9481, min: -3944.6443, mean: -217.6021, std: 749.9688
#
# 	node counts: max: 18, min: 11, mean: 13.83
#  	conn counts: max: 33, min: 15, mean: 21.63
#  	species: 10, [59, 39, 47, 37, 30, 26, 17, 18, 10, 17]
#
# Generation: 45, Cost time: 3229.69ms
#  	fitness: valid cnt: 300, max: 126.7917, min: -3944.2490, mean: -179.3711, std: 631.4168
#
# 	node counts: max: 18, min: 12, mean: 13.93
#  	conn counts: max: 29, min: 13, mean: 21.85
#  	species: 10, [52, 54, 37, 27, 34, 1, 23, 16, 14, 42]
#
# Generation: 46, Cost time: 3223.46ms
#  	fitness: valid cnt: 300, max: 135.9252, min: -3952.7451, mean: -302.9938, std: 827.7271
#
# 	node counts: max: 17, min: 12, mean: 14.03
#  	conn counts: max: 30, min: 15, mean: 21.97
#  	species: 10, [64, 50, 3, 1, 32, 24, 22, 16, 12, 76]
#
# Generation: 47, Cost time: 3254.21ms
#  	fitness: valid cnt: 300, max: 151.4678, min: -3517.5288, mean: -144.2335, std: 582.0557
#
# 	node counts: max: 18, min: 12, mean: 14.40
#  	conn counts: max: 30, min: 13, mean: 23.21
#  	species: 10, [26, 56, 1, 44, 23, 25, 17, 18, 11, 79]
#
# Generation: 48, Cost time: 3241.24ms
#  	fitness: valid cnt: 300, max: 136.8526, min: -3950.2256, mean: -352.0456, std: 880.5312
#
# 	node counts: max: 17, min: 12, mean: 14.24
#  	conn counts: max: 32, min: 17, mean: 23.22
#  	species: 10, [52, 39, 31, 1, 27, 26, 19, 13, 13, 79]
#
# Generation: 49, Cost time: 3221.06ms
#  	fitness: valid cnt: 300, max: 133.4391, min: -3925.8242, mean: -436.0784, std: 1008.6134
#
# 	node counts: max: 18, min: 12, mean: 14.41
#  	conn counts: max: 30, min: 15, mean: 22.48
#  	species: 10, [102, 53, 1, 33, 35, 1, 19, 12, 9, 35]
#
# Generation: 50, Cost time: 3258.22ms
#  	fitness: valid cnt: 300, max: 125.8543, min: -3949.9158, mean: -209.1168, std: 731.7506
#
# 	node counts: max: 18, min: 12, mean: 14.68
#  	conn counts: max: 32, min: 14, mean: 23.31
#  	species: 10, [74, 40, 50, 35, 32, 13, 20, 14, 12, 10]
#
# Generation limit reached!
#
# Training finished. Best fitness achieved: 151.46775817871094
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>compute_ms</td><td>▆▄▃▄▄▅▆▄▅▅▅▄▃▄▆▅▅▄▄▅▄▆▅▃▃██▇███▃▅▁▁▁▁▂▂▂</td></tr><tr><td>compute_ms_pop</td><td>▆▄▃▄▄▅▅▄▅▄▅▄▃▄▆▄▅▄▄▅▄▆▅▃▃██▇▆▇███▅▁▂▁▂▂▂</td></tr><tr><td>fitness_max</td><td>▁▁▄▅▆▅▅▅▆▇▅▆▆▅▆▇▆▇▇▆▆▅▅▅▆▅▆▅▆▇▆▇▆▅▆▇▆▇█▆</td></tr><tr><td>fitness_mean</td><td>▁▆▇████▇██▇██▇▇██▇▇▇▇▇▇▇▇▇▇▆▇▇▇▇▇▇▇▇▇▇▆▇</td></tr><tr><td>fitness_min</td><td>▁▁▁▁▁▃▁██▅▁▇█▁▃██▁▁▄▁▄▃▁▁▁▁▁▁█▁▂▁█▁▁▁▇▁▁</td></tr><tr><td>fitness_std</td><td>█▆▃▁▂▁▁▃▂▁▃▃▂▂▃▃▂▃▄▄▂▄▃▄▄▅▅▄▄▄▄▄▄▂▄▃▄▂▅▄</td></tr><tr><td>generation</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>num_species</td><td>███████████████████████▁█████▁██████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>compute_ms</td><td>3258.22425</td></tr><tr><td>compute_ms_pop</td><td>10.86075</td></tr><tr><td>fitness_max</td><td>125.85429</td></tr><tr><td>fitness_mean</td><td>-209.11678</td></tr><tr><td>fitness_min</td><td>-3949.91577</td></tr><tr><td>fitness_std</td><td>731.75061</td></tr><tr><td>generation</td><td>50</td></tr><tr><td>num_species</td><td>10</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ant_manual_simple_2d</strong> at: <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/x0nk9rls' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/x0nk9rls</a><br> View project at: <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_configuration</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251103_103342-x0nk9rls/logs</code>
# initializing
# initializing finished
# 2025-11-03 10:37:08.699115: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-03 10:37:08.699130: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# Total reward:  124.771614
# /home/andi/anaconda3/envs/jax/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
# mp4 saved to:  output/ant/video/agent_manual_simple_1fd.mp4
# Visualizing CPPN. Saving to output/ant/topology/cppn_manual_simple_1fd.svg.
# Manually reconstructing the phenotype. A visual layout will be generated.
# Substrate has 1792 potential connections.
# Visualizing 1694 connections. Excluded loops. Weight threshold: 0.005
# Visualization saved to: output/ant/topology/nn_manual_simple_1fd.svg
# Successfully saved coordinates to: output/ant/coordinates/manual_simple_1fd_io.csv
# Intial CPPN Layers: [2]
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/andi/Dokumente/Bachelorarbeit/dim_tuning/wandb/run-20251103_103730-63xcfqfc</code>
# Syncing run <strong><a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/63xcfqfc' target="_blank">ant_manual_mapping_10d</a></strong> to <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_configuration</a>
#  View run at <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/63xcfqfc' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/63xcfqfc</a>
# save to output/ant/genome/manual_mapping_9fd
# initializing
# initializing finished
# start compile
# compile finished, cost time: 29.449181s
# Generation: 1, Cost time: 3314.76ms
#  	fitness: valid cnt: 300, max: 53.3209, min: -3953.9468, mean: -1262.6473, std: 1263.5568
#
# 	node counts: max: 24, min: 22, mean: 23.25
#  	conn counts: max: 44, min: 21, mean: 42.26
#  	species: 10, [20, 78, 65, 12, 26, 8, 14, 26, 6, 45]
#
# Generation: 2, Cost time: 3249.06ms
#  	fitness: valid cnt: 300, max: 52.4997, min: -3459.1475, mean: -194.4696, std: 610.8600
#
# 	node counts: max: 25, min: 22, mean: 23.20
#  	conn counts: max: 45, min: 21, mean: 39.40
#  	species: 10, [70, 46, 49, 43, 1, 1, 1, 39, 25, 25]
#
# Generation: 3, Cost time: 3281.05ms
#  	fitness: valid cnt: 300, max: 53.5066, min: -3952.6558, mean: -66.7121, std: 503.8166
#
# 	node counts: max: 25, min: 22, mean: 23.48
#  	conn counts: max: 46, min: 21, mean: 39.83
#  	species: 10, [50, 1, 46, 42, 28, 25, 30, 10, 9, 59]
#
# Generation: 4, Cost time: 3309.55ms
#  	fitness: valid cnt: 300, max: 52.9833, min: -3947.6379, mean: -94.0603, std: 629.9196
#
# 	node counts: max: 26, min: 21, mean: 23.76
#  	conn counts: max: 48, min: 2, mean: 41.17
#  	species: 10, [50, 47, 26, 1, 30, 33, 15, 20, 20, 58]
#
# Generation: 5, Cost time: 3341.68ms
#  	fitness: valid cnt: 300, max: 53.3635, min: -3806.8022, mean: -87.8565, std: 556.5128
#
# 	node counts: max: 27, min: 21, mean: 24.07
#  	conn counts: max: 49, min: 1, mean: 41.66
#  	species: 10, [50, 1, 34, 26, 31, 37, 20, 23, 15, 63]
#
# Generation: 6, Cost time: 3281.98ms
#  	fitness: valid cnt: 300, max: 54.5044, min: -3955.9092, mean: -117.7396, std: 671.5391
#
# 	node counts: max: 27, min: 22, mean: 24.51
#  	conn counts: max: 49, min: 22, mean: 43.01
#  	species: 10, [49, 1, 39, 32, 33, 25, 20, 23, 12, 66]
#
# Generation: 7, Cost time: 3279.70ms
#  	fitness: valid cnt: 300, max: 56.1718, min: -3468.4321, mean: -80.3942, std: 533.9075
#
# 	node counts: max: 28, min: 22, mean: 24.88
#  	conn counts: max: 50, min: 21, mean: 43.63
#  	species: 10, [49, 1, 31, 31, 32, 30, 30, 19, 10, 67]
#
# Generation: 8, Cost time: 3259.88ms
#  	fitness: valid cnt: 300, max: 55.3500, min: -3477.1584, mean: -24.1907, std: 393.4500
#
# 	node counts: max: 28, min: 22, mean: 25.04
#  	conn counts: max: 51, min: 21, mean: 43.78
#  	species: 10, [49, 1, 36, 34, 30, 29, 20, 23, 9, 69]
#
# Generation: 9, Cost time: 3285.26ms
#  	fitness: valid cnt: 300, max: 55.4333, min: -3955.0840, mean: -97.3243, std: 593.3130
#
# 	node counts: max: 29, min: 23, mean: 25.43
#  	conn counts: max: 51, min: 22, mean: 44.11
#  	species: 10, [49, 1, 39, 33, 31, 23, 27, 19, 10, 68]
#
# Generation: 10, Cost time: 3283.49ms
#  	fitness: valid cnt: 300, max: 53.0330, min: -3948.8096, mean: -91.0725, std: 578.5728
#
# 	node counts: max: 29, min: 23, mean: 25.88
#  	conn counts: max: 52, min: 23, mean: 45.49
#  	species: 10, [49, 43, 35, 1, 31, 18, 27, 17, 16, 63]
#
# Generation: 11, Cost time: 3261.72ms
#  	fitness: valid cnt: 300, max: 53.0956, min: -3471.0486, mean: -83.4067, std: 525.6923
#
# 	node counts: max: 29, min: 23, mean: 26.26
#  	conn counts: max: 52, min: 23, mean: 45.46
#  	species: 10, [51, 41, 34, 1, 24, 35, 25, 16, 9, 64]
#
# Generation: 12, Cost time: 3295.07ms
#  	fitness: valid cnt: 300, max: 53.1991, min: -3457.4009, mean: -34.1699, std: 388.6947
#
# 	node counts: max: 29, min: 22, mean: 26.31
#  	conn counts: max: 53, min: 23, mean: 45.66
#  	species: 10, [49, 45, 39, 1, 28, 21, 22, 25, 10, 60]
#
# Generation: 13, Cost time: 3325.80ms
#  	fitness: valid cnt: 300, max: 55.8126, min: -3458.6572, mean: -38.4726, std: 425.6429
#
# 	node counts: max: 29, min: 23, mean: 26.44
#  	conn counts: max: 53, min: 21, mean: 45.54
#  	species: 10, [47, 47, 32, 1, 35, 24, 23, 13, 19, 59]
#
# Generation: 14, Cost time: 3275.82ms
#  	fitness: valid cnt: 300, max: 55.7422, min: -3954.1536, mean: -66.4027, std: 544.9070
#
# 	node counts: max: 30, min: 22, mean: 26.82
#  	conn counts: max: 54, min: 22, mean: 45.49
#  	species: 10, [47, 40, 45, 1, 28, 31, 22, 14, 14, 58]
#
# Generation: 15, Cost time: 3301.23ms
#  	fitness: valid cnt: 300, max: 55.9446, min: -3951.5581, mean: -147.1164, std: 726.5774
#
# 	node counts: max: 30, min: 23, mean: 27.31
#  	conn counts: max: 54, min: 23, mean: 46.19
#  	species: 10, [47, 38, 41, 26, 27, 29, 33, 1, 12, 46]
#
# Generation: 16, Cost time: 3313.82ms
#  	fitness: valid cnt: 300, max: 55.0056, min: -3952.7322, mean: -103.9339, std: 668.8172
#
# 	node counts: max: 29, min: 23, mean: 27.38
#  	conn counts: max: 54, min: 24, mean: 45.44
#  	species: 10, [53, 45, 34, 35, 1, 27, 10, 22, 24, 49]
#
# Generation: 17, Cost time: 3280.38ms
#  	fitness: valid cnt: 300, max: 55.0051, min: -3727.4209, mean: -87.7903, std: 590.8550
#
# 	node counts: max: 29, min: 23, mean: 27.75
#  	conn counts: max: 54, min: 24, mean: 45.83
#  	species: 10, [67, 37, 45, 37, 1, 25, 27, 11, 9, 41]
#
# Generation: 18, Cost time: 3283.46ms
#  	fitness: valid cnt: 300, max: 55.3138, min: -3951.1973, mean: -182.5191, std: 761.8055
#
# 	node counts: max: 29, min: 23, mean: 27.64
#  	conn counts: max: 54, min: 23, mean: 46.42
#  	species: 10, [58, 43, 42, 37, 38, 27, 23, 13, 10, 9]
#
# Generation: 19, Cost time: 3307.28ms
#  	fitness: valid cnt: 300, max: 56.2352, min: -3952.5522, mean: -139.7184, std: 718.8748
#
# 	node counts: max: 30, min: 23, mean: 27.74
#  	conn counts: max: 54, min: 25, mean: 46.43
#  	species: 9, [67, 47, 42, 38, 38, 24, 14, 20, 10]
#
# Generation: 20, Cost time: 3265.65ms
#  	fitness: valid cnt: 300, max: 56.2742, min: -3491.6243, mean: -58.0114, std: 513.0228
#
# 	node counts: max: 30, min: 23, mean: 27.61
#  	conn counts: max: 54, min: 14, mean: 46.54
#  	species: 10, [64, 50, 42, 27, 36, 24, 29, 16, 10, 2]
#
# Generation: 21, Cost time: 3220.88ms
#  	fitness: valid cnt: 300, max: 56.1282, min: -3913.0696, mean: -79.2394, std: 531.4009
#
# 	node counts: max: 31, min: 22, mean: 28.38
#  	conn counts: max: 56, min: 14, mean: 47.28
#  	species: 10, [56, 49, 42, 36, 24, 27, 24, 22, 10, 10]
#
# Generation: 22, Cost time: 3179.43ms
#  	fitness: valid cnt: 300, max: 55.6339, min: -3689.8486, mean: -120.0067, std: 598.9258
#
# 	node counts: max: 31, min: 22, mean: 28.42
#  	conn counts: max: 56, min: 23, mean: 48.03
#  	species: 10, [57, 36, 32, 40, 1, 38, 22, 21, 33, 20]
#
# Generation: 23, Cost time: 3209.43ms
#  	fitness: valid cnt: 300, max: 55.6407, min: -3951.4976, mean: -96.8684, std: 587.8647
#
# 	node counts: max: 32, min: 23, mean: 28.61
#  	conn counts: max: 57, min: 26, mean: 46.25
#  	species: 10, [77, 1, 39, 36, 35, 24, 20, 9, 23, 36]
#
# Generation: 24, Cost time: 3185.10ms
#  	fitness: valid cnt: 300, max: 55.7758, min: -3460.8894, mean: -55.6016, std: 450.3509
#
# 	node counts: max: 32, min: 23, mean: 29.24
#  	conn counts: max: 58, min: 26, mean: 45.82
#  	species: 10, [78, 46, 40, 38, 34, 17, 22, 15, 9, 1]
#
# Generation: 25, Cost time: 3180.94ms
#  	fitness: valid cnt: 300, max: 56.3827, min: -3948.8032, mean: -119.8811, std: 627.3939
#
# 	node counts: max: 33, min: 23, mean: 29.91
#  	conn counts: max: 58, min: 26, mean: 45.51
#  	species: 10, [63, 42, 30, 36, 39, 33, 21, 15, 11, 10]
#
# Generation: 26, Cost time: 3185.29ms
#  	fitness: valid cnt: 300, max: 55.3308, min: -3949.6589, mean: -90.9745, std: 556.5382
#
# 	node counts: max: 33, min: 23, mean: 30.13
#  	conn counts: max: 60, min: 26, mean: 46.62
#  	species: 10, [60, 41, 41, 47, 26, 28, 18, 26, 10, 3]
#
# Generation: 27, Cost time: 3183.67ms
#  	fitness: valid cnt: 300, max: 56.3736, min: -3948.6953, mean: -69.9808, std: 524.8392
#
# 	node counts: max: 33, min: 23, mean: 30.53
#  	conn counts: max: 60, min: 25, mean: 47.42
#  	species: 10, [56, 45, 34, 39, 46, 27, 23, 13, 14, 3]
#
# Generation: 28, Cost time: 3246.92ms
#  	fitness: valid cnt: 300, max: 55.8217, min: -3934.3083, mean: -114.0751, std: 632.0961
#
# 	node counts: max: 33, min: 23, mean: 30.81
#  	conn counts: max: 61, min: 25, mean: 48.69
#  	species: 10, [56, 47, 41, 41, 27, 30, 17, 21, 1, 19]
#
# Generation: 29, Cost time: 3342.26ms
#  	fitness: valid cnt: 300, max: 56.4118, min: -3477.7754, mean: -81.3613, std: 542.4528
#
# 	node counts: max: 33, min: 25, mean: 30.86
#  	conn counts: max: 61, min: 29, mean: 48.88
#  	species: 10, [54, 45, 45, 39, 31, 24, 24, 16, 9, 13]
#
# Generation: 30, Cost time: 3348.73ms
#  	fitness: valid cnt: 300, max: 56.1639, min: -3465.8159, mean: -115.4250, std: 612.9802
#
# 	node counts: max: 34, min: 29, mean: 31.41
#  	conn counts: max: 63, min: 34, mean: 49.27
#  	species: 10, [1, 47, 33, 38, 38, 25, 17, 23, 56, 22]
#
# Generation: 31, Cost time: 3236.71ms
#  	fitness: valid cnt: 300, max: 56.4095, min: -3907.7974, mean: -14.6860, std: 342.9156
#
# 	node counts: max: 35, min: 28, mean: 31.77
#  	conn counts: max: 64, min: 32, mean: 51.63
#  	species: 9, [84, 52, 44, 2, 28, 31, 20, 9, 30]
#
# Generation: 32, Cost time: 3298.83ms
#  	fitness: valid cnt: 300, max: 56.0630, min: -3950.0796, mean: -75.1123, std: 580.1973
#
# 	node counts: max: 35, min: 29, mean: 31.99
#  	conn counts: max: 64, min: 34, mean: 52.12
#  	species: 9, [32, 68, 45, 35, 42, 28, 24, 16, 10]
#
# Generation: 33, Cost time: 3303.53ms
#  	fitness: valid cnt: 300, max: 55.6987, min: -3926.1714, mean: -52.4715, std: 475.5231
#
# 	node counts: max: 36, min: 28, mean: 32.09
#  	conn counts: max: 66, min: 33, mean: 52.08
#  	species: 9, [65, 42, 37, 41, 34, 35, 18, 18, 10]
#
# Generation: 34, Cost time: 3376.63ms
#  	fitness: valid cnt: 300, max: 56.2520, min: -3951.3394, mean: -91.2280, std: 600.5368
#
# 	node counts: max: 35, min: 28, mean: 32.02
#  	conn counts: max: 61, min: 33, mean: 51.85
#  	species: 8, [77, 50, 45, 39, 34, 29, 13, 13]
#
# Generation: 35, Cost time: 3384.81ms
#  	fitness: valid cnt: 300, max: 56.0932, min: -3587.1233, mean: -46.8104, std: 406.1377
#
# 	node counts: max: 36, min: 28, mean: 32.41
#  	conn counts: max: 63, min: 33, mean: 52.60
#  	species: 10, [59, 65, 42, 43, 31, 32, 14, 10, 2, 2]
#
# Generation: 36, Cost time: 3417.85ms
#  	fitness: valid cnt: 300, max: 55.8653, min: -2975.8137, mean: -57.7593, std: 390.8216
#
# 	node counts: max: 36, min: 28, mean: 33.19
#  	conn counts: max: 63, min: 34, mean: 52.36
#  	species: 9, [81, 56, 44, 35, 17, 18, 26, 13, 10]
#
# Generation: 37, Cost time: 3281.98ms
#  	fitness: valid cnt: 300, max: 55.8607, min: -3823.9407, mean: -100.5604, std: 515.3302
#
# 	node counts: max: 36, min: 29, mean: 33.26
#  	conn counts: max: 64, min: 35, mean: 52.28
#  	species: 9, [72, 54, 40, 42, 29, 19, 19, 15, 10]
#
# Generation: 38, Cost time: 3262.82ms
#  	fitness: valid cnt: 300, max: 56.2095, min: -3378.1938, mean: -43.6589, std: 409.9382
#
# 	node counts: max: 36, min: 29, mean: 33.29
#  	conn counts: max: 64, min: 36, mean: 52.08
#  	species: 9, [68, 53, 43, 29, 37, 27, 19, 14, 10]
#
# Generation: 39, Cost time: 3344.42ms
#  	fitness: valid cnt: 300, max: 56.2881, min: -1963.4272, mean: -19.5278, std: 290.4714
#
# 	node counts: max: 37, min: 29, mean: 33.29
#  	conn counts: max: 64, min: 34, mean: 52.97
#  	species: 9, [59, 60, 41, 41, 30, 22, 24, 13, 10]
#
# Generation: 40, Cost time: 3424.70ms
#  	fitness: valid cnt: 300, max: 56.8870, min: -3947.4580, mean: -87.9737, std: 553.1675
#
# 	node counts: max: 37, min: 29, mean: 33.47
#  	conn counts: max: 64, min: 34, mean: 53.67
#  	species: 9, [61, 56, 43, 40, 31, 25, 21, 13, 10]
#
# Generation: 41, Cost time: 3425.18ms
#  	fitness: valid cnt: 300, max: 57.2061, min: -3485.0046, mean: -27.2439, std: 365.3531
#
# 	node counts: max: 38, min: 30, mean: 33.94
#  	conn counts: max: 66, min: 22, mean: 54.46
#  	species: 10, [62, 54, 44, 40, 27, 28, 22, 12, 10, 1]
#
# Generation: 42, Cost time: 3419.11ms
#  	fitness: valid cnt: 300, max: 56.5395, min: -3475.3975, mean: -79.3644, std: 523.8864
#
# 	node counts: max: 37, min: 29, mean: 33.93
#  	conn counts: max: 66, min: 22, mean: 52.97
#  	species: 10, [55, 55, 35, 41, 36, 27, 10, 19, 11, 11]
#
# Generation: 43, Cost time: 3354.84ms
#  	fitness: valid cnt: 300, max: 56.5952, min: -2992.6445, mean: -103.9919, std: 510.5928
#
# 	node counts: max: 37, min: 30, mean: 34.27
#  	conn counts: max: 66, min: 22, mean: 54.36
#  	species: 9, [73, 54, 41, 37, 37, 22, 15, 11, 10]
#
# Generation: 44, Cost time: 3352.11ms
#  	fitness: valid cnt: 300, max: 55.7090, min: -3462.9749, mean: -54.1562, std: 401.6898
#
# 	node counts: max: 38, min: 31, mean: 34.83
#  	conn counts: max: 68, min: 22, mean: 54.61
#  	species: 8, [90, 56, 45, 39, 27, 20, 13, 10]
#
# Generation: 45, Cost time: 3359.26ms
#  	fitness: valid cnt: 300, max: 56.5014, min: -2489.4502, mean: -53.5203, std: 362.9684
#
# 	node counts: max: 38, min: 32, mean: 34.90
#  	conn counts: max: 69, min: 22, mean: 54.22
#  	species: 8, [79, 57, 47, 40, 30, 19, 18, 10]
#
# Generation: 46, Cost time: 3381.23ms
#  	fitness: valid cnt: 300, max: 56.5808, min: -3947.7910, mean: -59.3532, std: 441.0162
#
# 	node counts: max: 38, min: 32, mean: 34.99
#  	conn counts: max: 70, min: 20, mean: 53.36
#  	species: 8, [74, 57, 34, 30, 36, 36, 23, 10]
#
# Generation: 47, Cost time: 3264.90ms
#  	fitness: valid cnt: 300, max: 56.4428, min: -2750.7305, mean: -3.9358, std: 234.5731
#
# 	node counts: max: 39, min: 32, mean: 35.42
#  	conn counts: max: 72, min: 23, mean: 54.31
#  	species: 8, [73, 57, 43, 38, 31, 29, 19, 10]
#
# Generation: 48, Cost time: 3254.61ms
#  	fitness: valid cnt: 300, max: 56.0008, min: -2187.8093, mean: -36.1435, std: 329.1637
#
# 	node counts: max: 39, min: 32, mean: 35.38
#  	conn counts: max: 72, min: 20, mean: 54.51
#  	species: 8, [64, 65, 46, 36, 26, 31, 22, 10]
#
# Generation: 49, Cost time: 3254.18ms
#  	fitness: valid cnt: 300, max: 56.5006, min: -3460.9604, mean: -98.5952, std: 552.0886
#
# 	node counts: max: 40, min: 32, mean: 36.02
#  	conn counts: max: 73, min: 24, mean: 55.97
#  	species: 8, [68, 61, 48, 33, 27, 30, 23, 10]
#
# Generation: 50, Cost time: 3369.72ms
#  	fitness: valid cnt: 300, max: 55.7852, min: -3960.0901, mean: -79.2450, std: 478.6501
#
# 	node counts: max: 40, min: 32, mean: 36.15
#  	conn counts: max: 73, min: 21, mean: 56.42
#  	species: 8, [65, 63, 49, 37, 31, 26, 19, 10]
#
# Generation limit reached!
#
# Training finished. Best fitness achieved: 57.20606231689453
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>compute_ms</td><td>▅▃▄▅▆▄▃▄▄▃▅▄▄▅▄▅▃▂▁▂▁▁▃▆▆▄▅▇█▄▆███▆▆▇▃▃▆</td></tr><tr><td>compute_ms_pop</td><td>▅▃▄▅▆▄▃▄▄▃▅▄▄▅▄▅▃▂▁▂▁▃▆▆▃▅▇▇█▄▆███▆▆▇▃▃▆</td></tr><tr><td>fitness_max</td><td>▂▁▂▂▂▆▅▅▂▂▆▆▆▅▅▇▇▆▆▆▅▇▆▇▆▆▇▆▆▆▇██▇▇▇▇▇▆▆</td></tr><tr><td>fitness_mean</td><td>▁▇█▇███████▇▇█▇██▇▇██▇█▇█████▇████▇█████</td></tr><tr><td>fitness_min</td><td>▁▃▁▁▂▃▃▁▁▃▃▁▁▁▂▁▃▁▂▁▁▁▁▁▃▁▁▁▂▄▃█▁▃▃▃▆▁▇▁</td></tr><tr><td>fitness_std</td><td>█▄▃▄▃▂▃▃▃▂▃▄▃▅▄▃▃▃▂▄▃▄▃▄▂▃▃▂▂▃▁▃▂▃▃▂▂▁▂▃</td></tr><tr><td>generation</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>num_species</td><td>████████████████████████▅▅▁█▅▅▅▅██▅▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>compute_ms</td><td>3369.72046</td></tr><tr><td>compute_ms_pop</td><td>11.2324</td></tr><tr><td>fitness_max</td><td>55.78516</td></tr><tr><td>fitness_mean</td><td>-79.245</td></tr><tr><td>fitness_min</td><td>-3960.09009</td></tr><tr><td>fitness_std</td><td>478.65015</td></tr><tr><td>generation</td><td>50</td></tr><tr><td>num_species</td><td>8</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ant_manual_mapping_10d</strong> at: <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/63xcfqfc' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/63xcfqfc</a><br> View project at: <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_configuration</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251103_103730-63xcfqfc/logs</code>
# initializing
# initializing finished
# Total reward:  56.822285
# /home/andi/anaconda3/envs/jax/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
# mp4 saved to:  output/ant/video/agent_manual_mapping_9fd.mp4
# Visualizing CPPN. Saving to output/ant/topology/cppn_manual_mapping_9fd.svg.
# Manually reconstructing the phenotype. A visual layout will be generated.
# Substrate has 1792 potential connections.
# Visualizing 1623 connections. Excluded loops. Weight threshold: 0.005
# Visualization saved to: output/ant/topology/nn_manual_mapping_9fd.svg
# Successfully saved coordinates to: output/ant/coordinates/manual_mapping_9fd_io.csv
# Intial CPPN Layers: [2]
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/andi/Dokumente/Bachelorarbeit/dim_tuning/wandb/run-20251103_104113-n85qlwox</code>
# Syncing run <strong><a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/n85qlwox' target="_blank">ant_trained_ica_2d</a></strong> to <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_configuration</a>
#  View run at <a href='https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/n85qlwox' target="_blank">https://wandb.ai/wirkelzirkel-iu/substrate_configuration/runs/n85qlwox</a>
# save to output/ant/genome/trained_ica_1fd
# initializing
# initializing finished
# start compile
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2297, in _lower_jaxpr_to_fun_cached(ctx, fn_name, call_jaxpr, effects, name_stack, arg_names, result_names)
#    2296 try:
# -> 2297   func_op = ctx.cached_primitive_lowerings[key]
#    2298 except KeyError:
#
# KeyError: (None, let _take = { lambda ; a:f32[9,3] b:i32[1,0]. let
#     _:i32[1,0] = pjit[
#       name=remainder
#       jaxpr={ lambda ; b:i32[1,0] c:i32[]. let
#           d:bool[] = eq c 0:i32[]
#           e:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; d:bool[] f:i32[] c:i32[]. let
#                 e:i32[] = select_n d c f
#               in (e,) }
#           ] d 1:i32[] c
#           g:i32[1,0] = rem b e
#           h:bool[1,0] = ne g 0:i32[]
#           i:bool[1,0] = lt g 0:i32[]
#           j:bool[] = lt e 0:i32[]
#           k:bool[1,0] = ne i j
#           l:bool[1,0] = and k h
#           m:i32[1,0] = add g e
#           _:i32[1,0] = select_n l g m
#         in (_,) }
#     ] b 9:i32[]
#     n:f32[1,0,3] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1, 0, 3)
#       sharding=None
#     ] 0.0:f32[]
#   in (n,) } in
# let _take1 = { lambda ; o:f32[1,0,3] p:i32[1]. let
#     q:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; p:i32[1] r:i32[]. let
#           s:bool[] = eq r 0:i32[]
#           t:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; d:bool[] f:i32[] c:i32[]. let
#                 e:i32[] = select_n d c f
#               in (e,) }
#           ] s 1:i32[] r
#           u:i32[1] = rem p t
#           v:bool[1] = ne u 0:i32[]
#           w:bool[1] = lt u 0:i32[]
#           x:bool[] = lt t 0:i32[]
#           y:bool[1] = ne w x
#           z:bool[1] = and y v
#           ba:i32[1] = add u t
#           q:i32[1] = select_n z u ba
#         in (q,) }
#     ] p 1:i32[]
#     bb:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] q
#     bc:f32[1,0,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1, 2), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 0, 3)
#       unique_indices=False
#     ] o bb
#   in (bc,) } in
# let _take2 = { lambda ; bd:f32[1,3,3] be:i32[1]. let
#     bf:i32[1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; p:i32[1] r:i32[]. let
#           s:bool[] = eq r 0:i32[]
#           t:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; d:bool[] f:i32[] c:i32[]. let
#                 e:i32[] = select_n d c f
#               in (e,) }
#           ] s 1:i32[] r
#           u:i32[1] = rem p t
#           v:bool[1] = ne u 0:i32[]
#           w:bool[1] = lt u 0:i32[]
#           x:bool[] = lt t 0:i32[]
#           y:bool[1] = ne w x
#           z:bool[1] = and y v
#           ba:i32[1] = add u t
#           q:i32[1] = select_n z u ba
#         in (q,) }
#     ] be 1:i32[]
#     bg:i32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(1, 1)
#       sharding=None
#     ] bf
#     bh:f32[1,3,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(1, 2), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 3, 3)
#       unique_indices=False
#     ] bd bg
#   in (bh,) } in
# let _take3 = { lambda ; bi:f32[9,3] bj:i32[1,1]. let
#     bk:i32[1,1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; bj:i32[1,1] bl:i32[]. let
#           bm:bool[] = eq bl 0:i32[]
#           bn:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; d:bool[] f:i32[] c:i32[]. let
#                 e:i32[] = select_n d c f
#               in (e,) }
#           ] bm 1:i32[] bl
#           bo:i32[1,1] = rem bj bn
#           bp:bool[1,1] = ne bo 0:i32[]
#           bq:bool[1,1] = lt bo 0:i32[]
#           br:bool[] = lt bn 0:i32[]
#           bs:bool[1,1] = ne bq br
#           bt:bool[1,1] = and bs bp
#           bu:i32[1,1] = add bo bn
#           bk:i32[1,1] = select_n bt bo bu
#         in (bk,) }
#     ] bj 9:i32[]
#     bv:i32[1,1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(1, 1, 1)
#       sharding=None
#     ] bk
#     bw:f32[1,1,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(2,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 3)
#       unique_indices=False
#     ] bi bv
#   in (bw,) } in
# let _take4 = { lambda ; bx:f32[300,8,15] by:i32[1,7]. let
#     bz:i32[1,7] = pjit[
#       name=remainder
#       jaxpr={ lambda ; by:i32[1,7] ca:i32[]. let
#           cb:bool[] = eq ca 0:i32[]
#           cc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; cb:bool[] cd:i32[] ca:i32[]. let
#                 cc:i32[] = select_n cb ca cd
#               in (cc,) }
#           ] cb 1:i32[] ca
#           ce:i32[1,7] = rem by cc
#           cf:bool[1,7] = ne ce 0:i32[]
#           cg:bool[1,7] = lt ce 0:i32[]
#           ch:bool[] = lt cc 0:i32[]
#           ci:bool[1,7] = ne cg ch
#           cj:bool[1,7] = and ci cf
#           ck:i32[1,7] = add ce cc
#           bz:i32[1,7] = select_n cj ce ck
#         in (bz,) }
#     ] by 15:i32[]
#     cl:i32[1,7,1] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(1, 7, 1)
#       sharding=None
#     ] bz
#     cm:f32[300,8,1,7] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(2,), start_index_map=(2,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(300, 8, 1)
#       unique_indices=False
#     ] bx cl
#   in (cm,) } in
# let _take5 = { lambda ; cn:f32[15] co:i32[1,7]. let
#     cp:i32[1,7] = pjit[
#       name=remainder
#       jaxpr={ lambda ; by:i32[1,7] ca:i32[]. let
#           cb:bool[] = eq ca 0:i32[]
#           cc:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; cb:bool[] cd:i32[] ca:i32[]. let
#                 cc:i32[] = select_n cb ca cd
#               in (cc,) }
#           ] cb 1:i32[] ca
#           ce:i32[1,7] = rem by cc
#           cf:bool[1,7] = ne ce 0:i32[]
#           cg:bool[1,7] = lt ce 0:i32[]
#           ch:bool[] = lt cc 0:i32[]
#           ci:bool[1,7] = ne cg ch
#           cj:bool[1,7] = and ci cf
#           ck:i32[1,7] = add ce cc
#           bz:i32[1,7] = select_n cj ce ck
#         in (bz,) }
#     ] co 15:i32[]
#     cq:i32[1,7,1] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(1, 7, 1)
#       sharding=None
#     ] cp
#     cr:f32[1,7] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1,)
#       unique_indices=False
#     ] cn cq
#   in (cr,) } in
# let allclose = { lambda ; cs:f32[300,8,1,4] ct:f32[]. let
#     cu:bool[300,8,1,4] = pjit[
#       name=isclose
#       jaxpr={ lambda ; cs:f32[300,8,1,4] ct:f32[] cv:f32[] cw:f32[]. let
#           cx:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ct
#           cy:f32[] = convert_element_type[new_dtype=float32 weak_type=False] cv
#           cz:f32[] = convert_element_type[new_dtype=float32 weak_type=False] cw
#           da:bool[300,8,1,4] = ne cs cs
#           db:bool[] = ne cx cx
#           _:bool[300,8,1,4] = and da db
#           dc:bool[] = is_finite cx
#           dd:f32[300,8,1,4] = sub cs cx
#           de:f32[300,8,1,4] = abs dd
#           df:f32[] = abs cx
#           dg:f32[] = mul cy df
#           dh:f32[] = add cz dg
#           di:bool[300,8,1,4] = le de dh
#           dj:bool[300,8,1,4] = eq cs cx
#           dk:bool[300,8,1,4] = and dc di
#           cu:bool[300,8,1,4] = or dj dk
#         in (cu,) }
#     ] cs ct 1e-05:f32[] 1e-08:f32[]
#     dl:bool[300,8,1] = reduce_and[axes=(3,)] cu
#   in (dl,) } in
# let _where = { lambda ; dm:bool[300,8,1] dn:f32[4] do:f32[300,8,1,4]. let
#     dp:f32[1,4] = broadcast_in_dim[
#       broadcast_dimensions=(1,)
#       shape=(1, 4)
#       sharding=None
#     ] dn
#     dq:bool[300,8,1,4] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(300, 8, 1, 4)
#       sharding=None
#     ] dm
#     dr:f32[8,1,4] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(8, 1, 4)
#       sharding=None
#     ] dp
#     ds:f32[300,8,1,4] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2, 3)
#       shape=(300, 8, 1, 4)
#       sharding=None
#     ] dr
#     dt:f32[300,8,1,4] = select_n dq do ds
#   in (dt,) } in
# let norm = { lambda ; du:f32[300,8,1,4]. let
#     dv:f32[300,8,1,4] = mul du du
#     dw:f32[300,8,1] = reduce_sum[axes=(3,)] dv
#     dx:f32[300,8,1] = sqrt dw
#   in (dx,) } in
# let _where1 = { lambda ; dy:bool[300,8,1] dz:f32[] ea:f32[300,8,1]. let
#     eb:f32[] = convert_element_type[new_dtype=float32 weak_type=False] dz
#     ec:f32[1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1,)
#       sharding=None
#     ] eb
#     ed:f32[8,1] = broadcast_in_dim[
#       broadcast_dimensions=(1,)
#       shape=(8, 1)
#       sharding=None
#     ] ec
#     ee:f32[300,8,1] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(300, 8, 1)
#       sharding=None
#     ] ed
#     ef:f32[300,8,1] = select_n dy ea ee
#   in (ef,) } in
# let _take6 = { lambda ; eg:f32[9,3] eh:i32[4,1]. let
#     ei:i32[4,1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; eh:i32[4,1] ej:i32[]. let
#           ek:bool[] = eq ej 0:i32[]
#           el:i32[] = pjit[
#             name=_where
#             jaxpr={ lambda ; d:bool[] f:i32[] c:i32[]. let
#                 e:i32[] = select_n d c f
#               in (e,) }
#           ] ek 1:i32[] ej
#           em:i32[4,1] = rem eh el
#           en:bool[4,1] = ne em 0:i32[]
#           eo:bool[4,1] = lt em 0:i32[]
#           ep:bool[] = lt el 0:i32[]
#           eq:bool[4,1] = ne eo ep
#           er:bool[4,1] = and eq en
#           es:i32[4,1] = add em el
#           ei:i32[4,1] = select_n er em es
#         in (ei,) }
#     ] eh 9:i32[]
#     et:i32[4,1,1] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(4, 1, 1)
#       sharding=None
#     ] ei
#     eu:f32[4,1,3] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(2,), collapsed_slice_dims=(0,), start_index_map=(0,), operand_batching_dims=(), start_indices_batching_dims=())
#       fill_value=None
#       indices_are_sorted=False
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 3)
#       unique_indices=False
#     ] eg et
#   in (eu,) } in
# let _take7 = { lambda ; ev:f32[300,8,15] ew:i32[4,1]. let
#     ex:i32[4,1] = pjit[
#       name=remainder
#       jaxpr={ lambda ; eh:i32[4,1] ej:i32[]. let
#           ek:bool[] = eq ej 0:i32[]
#           el:i32[] = pjit[
#             name=_where
# ...
#    2366                   dim_var_values: Sequence[ir.Value],
#    2367                   arg_names=None, result_names=None):
#    2368   del avals_in
# -> 2369   func_op, output_types, effects = lower_called_computation(
#    2370       fn_name, name_stack, call_jaxpr, ctx, avals_out, tokens_in,
#    2371       backend=backend, arg_names=arg_names, result_names=result_names)
#    2372   symbol_name = func_op.name.value
#    2373   flat_output_types = flatten_ir_types(output_types)
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2351, in lower_called_computation(fn_name, name_stack, call_jaxpr, ctx, avals_out, tokens_in, backend, arg_names, result_names)
#    2349 output_types = map(aval_to_ir_type, avals_out)
#    2350 output_types = [token_type()] * len(effects) + output_types
# -> 2351 func_op = _lower_jaxpr_to_fun_cached(
#    2352     ctx,
#    2353     fn_name,
#    2354     call_jaxpr,
#    2355     effects,
#    2356     name_stack,
#    2357     arg_names=arg_names,
#    2358     result_names=result_names,
#    2359 )
#    2360 return func_op, output_types, effects
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2300, in _lower_jaxpr_to_fun_cached(ctx, fn_name, call_jaxpr, effects, name_stack, arg_names, result_names)
#    2298 except KeyError:
#    2299   num_callbacks = len(ctx.host_callbacks)
# -> 2300   func_op = lower_jaxpr_to_fun(
#    2301       ctx, fn_name, call_jaxpr, effects, name_stack, arg_names=arg_names,
#    2302       result_names=result_names)
#    2304   # If this Jaxpr includes callbacks, we can't cache the lowering because
#    2305   # on TPU every callback must have a globally unique channel, but the
#    2306   # channel gets assigned during lowering.
#    2307   has_callbacks = len(ctx.host_callbacks) > num_callbacks
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1766, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, name_stack, public, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, api_name, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts, propagated_out_mem_kinds)
#    1764   callee_name_stack = name_stack
#    1765 consts = [ir_constant(xla.canonicalize_dtype(x)) for x in jaxpr.consts]
# -> 1766 out_vals, tokens_out = jaxpr_subcomp(
#    1767     ctx, jaxpr.jaxpr, callee_name_stack, tokens_in,
#    1768     consts, *args, dim_var_values=dim_var_values)
#    1769 outs: list[IrValues] = []
#    1770 for eff in effects:
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2043, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    2040   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
#    2042 assert all(_is_ir_values(v) for v in in_nodes), (eqn, in_nodes)
# -> 2043 ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    2044                          platform_rules, default_rule,
#    2045                          eqn.effects,
#    2046                          *in_nodes, **eqn.params)
#    2048 if effects:
#    2049   # If there were ordered effects in the primitive, there should be output
#    2050   # tokens we need for subsequent ordered effects.
#    2051   tokens_out = rule_ctx.tokens_out
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2165, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    2163 # If there is a single rule left just apply the rule, without conditionals.
#    2164 if len(kept_rules) == 1:
# -> 2165   output = kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    2166   foreach(
#    2167       lambda o: wrap_compute_type_in_place(ctx, o.owner),
#    2168       filter(_is_not_block_argument, flatten_ir_values(output)),
#    2169   )
#    2170   foreach(
#    2171       lambda o: wrap_xla_metadata_in_place(ctx, o.owner),
#    2172       flatten_ir_values(output),
#    2173   )
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2281, in lower_fun.<locals>.f_lowered(ctx, *args, **params)
#    2279 else:
#    2280   sub_context = ctx.module_context
# -> 2281 out, tokens = jaxpr_subcomp(
#    2282     sub_context, jaxpr, ctx.name_stack, ctx.tokens_in,
#    2283     _ir_consts(consts), *args,
#    2284     dim_var_values=ctx.dim_var_values)
#    2285 ctx.set_tokens_out(tokens)
#    2286 return out
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2043, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    2040   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
#    2042 assert all(_is_ir_values(v) for v in in_nodes), (eqn, in_nodes)
# -> 2043 ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    2044                          platform_rules, default_rule,
#    2045                          eqn.effects,
#    2046                          *in_nodes, **eqn.params)
#    2048 if effects:
#    2049   # If there were ordered effects in the primitive, there should be output
#    2050   # tokens we need for subsequent ordered effects.
#    2051   tokens_out = rule_ctx.tokens_out
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2165, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    2163 # If there is a single rule left just apply the rule, without conditionals.
#    2164 if len(kept_rules) == 1:
# -> 2165   output = kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    2166   foreach(
#    2167       lambda o: wrap_compute_type_in_place(ctx, o.owner),
#    2168       filter(_is_not_block_argument, flatten_ir_values(output)),
#    2169   )
#    2170   foreach(
#    2171       lambda o: wrap_xla_metadata_in_place(ctx, o.owner),
#    2172       flatten_ir_values(output),
#    2173   )
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:2193, in _while_lowering(ctx, cond_jaxpr, body_jaxpr, cond_nconsts, body_nconsts, *args)
#    2190 body_name_stack = name_stack.extend('body')
#    2191 body_consts = [mlir.ir_constant(xla.canonicalize_dtype(x))
#    2192                for x in body_jaxpr.consts]
# -> 2193 new_z, tokens_out = mlir.jaxpr_subcomp(
#    2194     ctx.module_context, body_jaxpr.jaxpr, body_name_stack,
#    2195     tokens_in, body_consts, *(y + z), dim_var_values=ctx.dim_var_values)
#    2196 out_tokens = [tokens_out.get(eff) for eff in body_effects]
#    2197 if batched:
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2043, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    2040   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
#    2042 assert all(_is_ir_values(v) for v in in_nodes), (eqn, in_nodes)
# -> 2043 ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    2044                          platform_rules, default_rule,
#    2045                          eqn.effects,
#    2046                          *in_nodes, **eqn.params)
#    2048 if effects:
#    2049   # If there were ordered effects in the primitive, there should be output
#    2050   # tokens we need for subsequent ordered effects.
#    2051   tokens_out = rule_ctx.tokens_out
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2165, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    2163 # If there is a single rule left just apply the rule, without conditionals.
#    2164 if len(kept_rules) == 1:
# -> 2165   output = kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    2166   foreach(
#    2167       lambda o: wrap_compute_type_in_place(ctx, o.owner),
#    2168       filter(_is_not_block_argument, flatten_ir_values(output)),
#    2169   )
#    2170   foreach(
#    2171       lambda o: wrap_xla_metadata_in_place(ctx, o.owner),
#    2172       flatten_ir_values(output),
#    2173   )
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2386, in core_call_lowering(ctx, name, backend, call_jaxpr, *args)
#    2384 def core_call_lowering(ctx: LoweringRuleContext,
#    2385                        *args, name, backend=None, call_jaxpr):
# -> 2386   out_nodes, tokens = call_lowering(
#    2387       name, ctx.name_stack, call_jaxpr, backend, ctx.module_context,
#    2388       ctx.avals_in, ctx.avals_out, ctx.tokens_in, *args,
#    2389       dim_var_values=ctx.dim_var_values)
#    2390   ctx.set_tokens_out(tokens)
#    2391   return out_nodes
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2369, in call_lowering(***failed resolving arguments***)
#    2363 def call_lowering(fn_name, name_stack, call_jaxpr, backend,
#    2364                   ctx: ModuleContext, avals_in,
#    2365                   avals_out, tokens_in, *args,
#    2366                   dim_var_values: Sequence[ir.Value],
#    2367                   arg_names=None, result_names=None):
#    2368   del avals_in
# -> 2369   func_op, output_types, effects = lower_called_computation(
#    2370       fn_name, name_stack, call_jaxpr, ctx, avals_out, tokens_in,
#    2371       backend=backend, arg_names=arg_names, result_names=result_names)
#    2372   symbol_name = func_op.name.value
#    2373   flat_output_types = flatten_ir_types(output_types)
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2351, in lower_called_computation(fn_name, name_stack, call_jaxpr, ctx, avals_out, tokens_in, backend, arg_names, result_names)
#    2349 output_types = map(aval_to_ir_type, avals_out)
#    2350 output_types = [token_type()] * len(effects) + output_types
# -> 2351 func_op = _lower_jaxpr_to_fun_cached(
#    2352     ctx,
#    2353     fn_name,
#    2354     call_jaxpr,
#    2355     effects,
#    2356     name_stack,
#    2357     arg_names=arg_names,
#    2358     result_names=result_names,
#    2359 )
#    2360 return func_op, output_types, effects
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2300, in _lower_jaxpr_to_fun_cached(ctx, fn_name, call_jaxpr, effects, name_stack, arg_names, result_names)
#    2298 except KeyError:
#    2299   num_callbacks = len(ctx.host_callbacks)
# -> 2300   func_op = lower_jaxpr_to_fun(
#    2301       ctx, fn_name, call_jaxpr, effects, name_stack, arg_names=arg_names,
#    2302       result_names=result_names)
#    2304   # If this Jaxpr includes callbacks, we can't cache the lowering because
#    2305   # on TPU every callback must have a globally unique channel, but the
#    2306   # channel gets assigned during lowering.
#    2307   has_callbacks = len(ctx.host_callbacks) > num_callbacks
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1766, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, name_stack, public, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, api_name, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts, propagated_out_mem_kinds)
#    1764   callee_name_stack = name_stack
#    1765 consts = [ir_constant(xla.canonicalize_dtype(x)) for x in jaxpr.consts]
# -> 1766 out_vals, tokens_out = jaxpr_subcomp(
#    1767     ctx, jaxpr.jaxpr, callee_name_stack, tokens_in,
#    1768     consts, *args, dim_var_values=dim_var_values)
#    1769 outs: list[IrValues] = []
#    1770 for eff in effects:
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:2009, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    2006 in_nodes = map(read, eqn.invars)
#    2007 source_info = eqn.source_info.replace(
#    2008     name_stack=name_stack + eqn.source_info.name_stack)
# -> 2009 loc = _source_info_to_location(ctx, eqn.primitive, source_info)
#    2010 with (source_info_util.user_context(eqn.source_info.traceback), loc,
#    2011       eqn.ctx.manager):
#    2012   override_rule = get_override_lowering_rule(eqn.primitive)
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:510, in _source_info_to_location(ctx, primitive, source_info)
#     508     loc = ir.Location.unknown()
#     509   else:
# --> 510     loc = _traceback_to_location(ctx, source_info.traceback)
#     511 else:
#     512   frame = source_info_util.user_frame(source_info)
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:471, in _traceback_to_location(ctx, tb)
#     469 codes, lastis = tb.raw_frames()
#     470 for i, code in enumerate(codes):
# --> 471   if not _is_user_file(ctx, code.co_filename):
#     472     continue
#     474   lasti = lastis[i]
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:452, in _is_user_file(ctx, file_name)
#     451 def _is_user_file(ctx: ModuleContext, file_name: str) -> bool:
# --> 452   is_user = ctx.traceback_caches.is_user_file_cache.get(file_name, None)
#     453   if is_user is not None:
#     454     return is_user
#
# KeyboardInterrupt:
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x78716872c8e0>> (for post_run_cell), with arguments args (<ExecutionResult object at 787151837d00, execution_count=5 error_before_exec=None error_in_exec= info=<ExecutionInfo object at 787151837f10, raw_cell="for data_label, data_dict in substrates.items():
#  .." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/andi/Dokumente/Bachelorarbeit/dim_tuning/neuroevolution.ipynb#X56sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:593, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     590     return
#     592 self._logger.info("resuming backend")
# --> 593 self.backend.interface.publish_resume()
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/wandb/sdk/interface/interface.py:787, in InterfaceBase.publish_resume(self)
#     785 def publish_resume(self) -> None:
#     786     resume = pb.ResumeRequest()
# --> 787     self._publish_resume(resume)
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/wandb/sdk/interface/interface_shared.py:294, in InterfaceShared._publish_resume(self, resume)
#     292 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     293     rec = self._make_request(resume=resume)
# --> 294     self._publish(rec)
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38     self._assign(record)
# ---> 39     self._sock_client.send_record_publish(record)
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:166, in SockClient.send_record_publish(self, record)
#     164 server_req.request_id = record.control.mailbox_slot
#     165 server_req.record_publish.CopyFrom(record)
# --> 166 self.send_server_request(server_req)
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:146, in SockClient.send_server_request(self, msg)
#     145 def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 146     self._send_message(msg)
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:143, in SockClient._send_message(self, msg)
#     141 header = struct.pack("<BI", ord("W"), raw_size)
#     142 with self._lock:
# --> 143     self._sendall_with_error_handle(header + data)
#
# File ~/anaconda3/envs/jax/lib/python3.10/site-packages/wandb/sdk/lib/sock_client.py:122, in SockClient._sendall_with_error_handle(self, data)
#     120 start_time = time.monotonic()
#     121 try:
# --> 122     sent = self._sock.send(data)
#     123     # sent equal to 0 indicates a closed socket
#     124     if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
eval_output_dir = f"{OUTPUT_DIR}/eval"
os.makedirs(eval_output_dir, exist_ok=True)

# Load CSV file and set categories
df = pd.read_csv("output/ant/summary_results.csv")
df['method'] = df['method'].astype('category')
df['sampling'] = df['sampling'].astype('category')
df['dimensionality'] = df['dimensionality'].astype('category')

# Main Effect: Method
plt.figure(figsize=(8, 5))
sns.barplot(x='method', y='max_fitness', data=df, errorbar='sd')
plt.title('Main Effect: Reduction Method')
plt.ylabel('Fitness Avg')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(os.path.join(eval_output_dir, "main_effect_method.png"))
plt.close()

# Main Effect: Sampling
plt.figure(figsize=(6, 5))
sns.barplot(x='sampling', y='max_fitness', data=df, errorbar='sd')
plt.title('Main Effect: Data Sampling')
plt.ylabel('Fitness Avg')
plt.tight_layout()
plt.savefig(os.path.join(eval_output_dir, "main_effect_sampling.png"))
plt.close()

# Main Effect: Dimensionality
plt.figure(figsize=(8, 5))
sns.barplot(x='dimensionality', y='max_fitness', data=df, errorbar='sd')
plt.title('Main Effect: Dimensionality')
plt.ylabel('Fitness Avg')
plt.tight_layout()
plt.savefig(os.path.join(eval_output_dir, "main_effect_dimensionality.png"))
plt.close()

# Interaction: Method × Sampling
plt.figure(figsize=(10, 6))
sns.pointplot(x='method', y='max_fitness', hue='sampling', data=df, errorbar='sd', dodge=True)
plt.title('Interaction: Reduction Method × Data Sampling')
plt.ylabel('Fitness Avg')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(os.path.join(eval_output_dir, "interaction_method_sampling.png"))
plt.close()

# Interaction: Method × Dimensionality
plt.figure(figsize=(10, 6))
sns.pointplot(x='dimensionality', y='max_fitness', hue='method', data=df, errorbar='sd', dodge=True)
plt.title('Interaction Effect: Method × Dimensionality')
plt.ylabel('Fitness Avg')
plt.tight_layout()
plt.savefig(os.path.join(eval_output_dir, "interaction_method_dimensionality.png"))
plt.close()

# Interaction: Sampling × Dimensionality
plt.figure(figsize=(10, 6))
sns.pointplot(x='dimensionality', y='max_fitness', hue='sampling', data=df, errorbar='sd', dodge=True)
plt.title('Interaction Effect: Sampling × Dimensionality')
plt.ylabel('Fitness Avg')
plt.tight_layout()
plt.savefig(os.path.join(eval_output_dir, "interaction_sampling_dimensionality.png"))
plt.close()
