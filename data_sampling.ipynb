# %% [markdown]
# # Problem-Specific Coordinate Generation for HyperNEAT Substrates

# %% [markdown]
# ## Setup
#
# The testing was done on a 16GB VRAM GPU with CUDA 12.8. VRAM usage is determined mainly by substrate and population size.

# %% [markdown]
# ### Imports
#
# This setup requires some dependencies, mainly TensorNEAT, JAX, numpy, matplotlib, NetworkX, scikit-learn and wandb for logging. Using a virtual environment (i.e. conda) is highly recommended. Python 3.10.18 was used in development and testing.

# %%
import jax
import numpy as np
from collections import defaultdict
import pickle

from config import config
from substrate_generation.data_sampling import collect_random_policy_data, collect_trained_agent_policy_data
from evol_pipeline.brax_env import CustomBraxEnv
from utils.utils import setup_folder_structure

# %% [markdown]
# A quick setup of the folder structure to avoid errors further down the line.

# %%
OUTPUT_DIR = config["experiment"]["output_dir"]
setup_folder_structure(OUTPUT_DIR)

# %% [markdown]
# ### Setup Environment
#
# [Brax environments](https://github.com/google/brax/tree/main/brax/envs) are used for this experiment through the [TensorNEAT wrapper](https://github.com/EMI-Group/tensorneat/tree/main/src/tensorneat/problem/rl).

# %%
env_name = config["experiment"]["env_name"]
env_problem = CustomBraxEnv(
    env_name=env_name,
    backend=config["environment"]["backend"],
    brax_args=config["environment"]["brax_args"],
    max_step=config["environment"]["max_step"],
    repeat_times=config["environment"]["repeat_times"],
    obs_normalization=False,
    sample_episodes=16,
)
obs_size = env_problem.input_shape[0]
act_size = env_problem.output_shape[0]

print("env_problem.input_shape: ", env_problem.input_shape)
print("env_problem.input_shape: ", env_problem.output_shape)
# Out:
# /home/andi/anaconda3/envs/jax/lib/python3.10/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# 2025-09-07 21:17:09.659398: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-09-07 21:17:20.697392: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# env_problem.input_shape:  (27,)
# env_problem.input_shape:  (8,)

# %% [markdown]
# ## Data Sampling
#
# Before we can apply data-driven approaches to the task of substrate generation, some data needs to be generated. This can either be done by generating random action or actually training an agent for a short period and then sampling from its action. Both data sampling methods are used for comparison.

# %% [markdown]
# ### Data Sampling Method 1: Trained Agent
#
# First, we train an number of agents for a few generations on a simple substrate for the sole purpose of sampling their actions.

# %%
key = jax.random.PRNGKey(config["experiment"]["seed"]) # Use seed from config
num_trained_agent_sampling = config["data_sampling"]["num_agents_to_sample"]
all_trained_agent_data = []
for i in range(num_trained_agent_sampling):
    print(f"\nTraining and sampling agent #{i+1}/{num_trained_agent_sampling}")
    key, subkey = jax.random.split(key)
    trained_agent_data_run = collect_trained_agent_policy_data(
        env_problem=env_problem,
        key=subkey,
        num_steps=config["data_sampling"]["sampling_steps"],
        training_config=config["data_sampling"]["trained_agent_sampling"]
    )
    all_trained_agent_data.append(trained_agent_data_run)

combined_trained_agent_data = np.vstack(all_trained_agent_data)

print(f"Data collection complete. Combined data from {num_trained_agent_sampling} trained agents.")
print(f"Shape of each run's data: {all_trained_agent_data[0].shape}")
print(f"Shape of combined trained agents data: {combined_trained_agent_data.shape}")
# Out:
# Training and sampling agent #1/2
#
# Starting Agent Training and Data Collection
# Configuring and training the agent...
# Query dimension for sampling:  4
# initializing
# initializing finished
# start compile
# compile finished, cost time: 32.839402s
# Generation: 1, Cost time: 6732.27ms
#  	fitness: valid cnt: 1000, max: 103.9364, min: -313.2156, mean: -209.9459, std: 94.1488
#
# 	node counts: max: 7, min: 5, mean: 6.06
#  	conn counts: max: 7, min: 0, mean: 4.62
#  	species: 20, [454, 2, 62, 1, 2, 4, 2, 298, 1, 5, 1, 5, 1, 4, 1, 3, 1, 1, 6, 146]
#
# Generation: 2, Cost time: 6652.57ms
#  	fitness: valid cnt: 1000, max: 102.6933, min: -314.9031, mean: -111.4713, std: 147.4896
#
# 	node counts: max: 8, min: 5, mean: 6.20
#  	conn counts: max: 8, min: 0, mean: 4.16
#  	species: 20, [120, 144, 312, 51, 9, 24, 30, 3, 25, 21, 1, 3, 15, 12, 11, 7, 6, 3, 1, 202]
#
# Generation: 3, Cost time: 6680.04ms
#  	fitness: valid cnt: 1000, max: 104.4815, min: -315.2883, mean: -20.1863, std: 148.7720
#
# 	node counts: max: 9, min: 5, mean: 6.38
#  	conn counts: max: 9, min: 0, mean: 3.87
#  	species: 20, [101, 137, 74, 6, 69, 36, 33, 38, 9, 39, 29, 18, 142, 17, 1, 1, 13, 11, 1, 225]
#
# Generation: 4, Cost time: 6572.12ms
#  	fitness: valid cnt: 1000, max: 102.9600, min: -310.3520, mean: 24.6022, std: 122.2140
#
# 	node counts: max: 10, min: 5, mean: 6.53
#  	conn counts: max: 10, min: 0, mean: 3.85
#  	species: 20, [24, 41, 86, 49, 63, 2, 64, 49, 136, 21, 35, 34, 36, 25, 20, 13, 14, 3, 1, 284]
#
# Generation: 5, Cost time: 6578.99ms
#  	fitness: valid cnt: 1000, max: 102.6710, min: -306.3408, mean: 28.6295, std: 121.7153
#
# 	node counts: max: 10, min: 5, mean: 6.51
#  	conn counts: max: 11, min: 0, mean: 3.52
#  	species: 20, [53, 2, 144, 47, 34, 44, 49, 44, 44, 35, 37, 60, 33, 25, 23, 14, 14, 6, 2, 290]
#
# Generation: 6, Cost time: 6582.92ms
#  	fitness: valid cnt: 1000, max: 104.6983, min: -308.2913, mean: 31.0779, std: 119.5686
#
# 	node counts: max: 10, min: 5, mean: 6.58
#  	conn counts: max: 10, min: 0, mean: 3.57
#  	species: 20, [108, 55, 1, 44, 46, 3, 134, 59, 32, 35, 37, 20, 21, 29, 31, 32, 9, 14, 4, 286]
#
# Generation: 7, Cost time: 6603.62ms
#  	fitness: valid cnt: 1000, max: 103.0289, min: -313.1272, mean: 36.7419, std: 115.4633
#
# 	node counts: max: 10, min: 5, mean: 6.56
#  	conn counts: max: 8, min: 0, mean: 3.52
#  	species: 20, [92, 65, 57, 57, 59, 123, 2, 39, 40, 29, 38, 30, 16, 35, 18, 21, 10, 14, 6, 249]
#
# Generation: 8, Cost time: 6628.06ms
#  	fitness: valid cnt: 1000, max: 103.6942, min: -311.7417, mean: 38.2688, std: 111.3717
#
# 	node counts: max: 10, min: 5, mean: 6.56
#  	conn counts: max: 9, min: 0, mean: 3.42
#  	species: 20, [80, 58, 10, 64, 119, 56, 28, 34, 49, 46, 40, 25, 39, 26, 25, 28, 16, 12, 7, 238]
#
# Generation: 9, Cost time: 6918.21ms
#  	fitness: valid cnt: 1000, max: 103.4763, min: -312.1665, mean: 39.5637, std: 108.4857
#
# 	node counts: max: 10, min: 5, mean: 6.75
#  	conn counts: max: 9, min: 0, mean: 3.57
#  	species: 20, [84, 112, 60, 51, 44, 42, 40, 19, 62, 38, 38, 29, 27, 32, 28, 20, 11, 1, 10, 252]
#
# Generation: 10, Cost time: 6873.44ms
#  	fitness: valid cnt: 1000, max: 104.3099, min: -309.2852, mean: 38.4828, std: 112.0811
#
# 	node counts: max: 10, min: 5, mean: 6.85
#  	conn counts: max: 10, min: 0, mean: 3.47
#  	species: 20, [88, 111, 40, 7, 21, 36, 53, 41, 44, 37, 41, 7, 37, 27, 26, 30, 16, 15, 2, 321]
#
# Generation: 11, Cost time: 6673.53ms
#  	fitness: valid cnt: 1000, max: 103.7950, min: -319.6550, mean: 49.7994, std: 100.1816
#
# 	node counts: max: 10, min: 5, mean: 6.79
#  	conn counts: max: 8, min: 0, mean: 3.37
#  	species: 20, [82, 123, 23, 56, 26, 1, 47, 47, 36, 7, 40, 26, 19, 21, 36, 17, 28, 17, 20, 328]
#
# Generation: 12, Cost time: 6770.23ms
#  	fitness: valid cnt: 1000, max: 104.6383, min: -316.3658, mean: 49.3866, std: 102.1138
#
# 	node counts: max: 10, min: 5, mean: 6.67
#  	conn counts: max: 9, min: 0, mean: 3.49
#  	species: 20, [87, 55, 112, 8, 54, 31, 35, 31, 52, 50, 25, 47, 39, 33, 21, 22, 23, 6, 11, 258]
#
# Generation: 13, Cost time: 6828.84ms
#  	fitness: valid cnt: 1000, max: 104.3432, min: -310.2318, mean: 39.4802, std: 113.8810
#
# 	node counts: max: 11, min: 5, mean: 6.63
#  	conn counts: max: 10, min: 0, mean: 3.28
#  	species: 20, [54, 63, 58, 27, 40, 51, 20, 31, 31, 16, 31, 66, 4, 91, 24, 36, 30, 14, 8, 305]
#
# Generation: 14, Cost time: 6855.90ms
#  	fitness: valid cnt: 1000, max: 103.7164, min: -316.9035, mean: 45.2704, std: 106.4869
#
# 	node counts: max: 11, min: 5, mean: 6.63
#  	conn counts: max: 10, min: 0, mean: 3.25
#  	species: 20, [64, 61, 11, 56, 6, 43, 13, 43, 35, 42, 46, 100, 26, 18, 23, 18, 18, 70, 10, 297]
#
# Generation: 15, Cost time: 6864.17ms
#  	fitness: valid cnt: 1000, max: 105.3004, min: -327.5305, mean: 44.8835, std: 104.5801
#
# 	node counts: max: 11, min: 5, mean: 6.71
#  	conn counts: max: 10, min: 0, mean: 3.26
#  	species: 20, [67, 69, 43, 43, 10, 110, 43, 38, 48, 24, 3, 40, 32, 42, 22, 5, 26, 2, 27, 306]
#
# Generation: 16, Cost time: 6859.32ms
#  	fitness: valid cnt: 1000, max: 103.7939, min: -329.5739, mean: 36.9106, std: 116.3108
#
# 	node counts: max: 11, min: 5, mean: 6.60
#  	conn counts: max: 9, min: 0, mean: 3.02
#  	species: 20, [40, 142, 32, 36, 14, 20, 40, 63, 44, 35, 43, 43, 1, 17, 17, 15, 13, 11, 32, 342]
#
# Generation: 17, Cost time: 6867.55ms
#  	fitness: valid cnt: 1000, max: 104.2362, min: -318.6242, mean: 37.9200, std: 115.9910
#
# 	node counts: max: 11, min: 5, mean: 6.66
#  	conn counts: max: 11, min: 0, mean: 3.17
#  	species: 20, [88, 41, 58, 13, 146, 29, 46, 17, 38, 25, 43, 28, 41, 21, 21, 12, 47, 16, 4, 266]
#
# Generation: 18, Cost time: 6841.41ms
#  	fitness: valid cnt: 1000, max: 104.2197, min: -307.0792, mean: 45.3929, std: 103.8231
#
# 	node counts: max: 11, min: 5, mean: 6.65
#  	conn counts: max: 10, min: 0, mean: 3.27
#  	species: 20, [51, 47, 43, 85, 12, 13, 66, 22, 40, 31, 118, 28, 45, 7, 26, 15, 37, 4, 6, 304]
#
# Generation: 19, Cost time: 6868.67ms
#  	fitness: valid cnt: 1000, max: 103.9898, min: -314.3352, mean: 43.7924, std: 107.8197
#
# 	node counts: max: 11, min: 5, mean: 6.77
#  	conn counts: max: 10, min: 0, mean: 3.56
#  	species: 20, [69, 83, 68, 1, 45, 52, 41, 109, 26, 37, 30, 33, 44, 20, 27, 10, 21, 11, 12, 261]
#
# Generation: 20, Cost time: 6870.62ms
#  	fitness: valid cnt: 1000, max: 104.1287, min: -311.6382, mean: 42.9230, std: 104.8157
#
# 	node counts: max: 12, min: 5, mean: 6.73
#  	conn counts: max: 10, min: 0, mean: 3.58
#  	species: 20, [43, 57, 24, 86, 7, 54, 24, 121, 28, 31, 32, 29, 32, 29, 18, 7, 27, 17, 45, 289]
#
# Generation: 21, Cost time: 6991.13ms
#  	fitness: valid cnt: 1000, max: 104.8919, min: -307.8057, mean: 40.0925, std: 110.9500
#
# 	node counts: max: 12, min: 5, mean: 6.74
#  	conn counts: max: 10, min: 0, mean: 3.42
#  	species: 20, [46, 64, 76, 45, 39, 11, 13, 122, 47, 20, 35, 25, 27, 17, 31, 22, 32, 19, 12, 297]
#
# Generation: 22, Cost time: 7065.64ms
#  	fitness: valid cnt: 1000, max: 105.2539, min: -312.9461, mean: 39.8007, std: 110.5929
#
# 	node counts: max: 12, min: 5, mean: 6.66
#  	conn counts: max: 9, min: 0, mean: 3.36
#  	species: 20, [79, 42, 64, 48, 27, 40, 35, 30, 41, 4, 43, 20, 99, 19, 25, 28, 16, 15, 1, 324]
#
# Generation: 23, Cost time: 7016.16ms
#  	fitness: valid cnt: 1000, max: 104.5677, min: -312.0023, mean: 31.9841, std: 117.6070
#
# 	node counts: max: 12, min: 5, mean: 6.76
#  	conn counts: max: 10, min: 0, mean: 3.33
#  	species: 20, [29, 100, 62, 38, 15, 42, 39, 44, 42, 7, 100, 34, 27, 23, 18, 7, 19, 23, 36, 295]
#
# Generation: 24, Cost time: 6730.58ms
#  	fitness: valid cnt: 1000, max: 104.6948, min: -341.0021, mean: 39.2704, std: 110.6504
#
# 	node counts: max: 11, min: 5, mean: 6.83
#  	conn counts: max: 10, min: 0, mean: 3.44
#  	species: 20, [63, 60, 21, 40, 46, 106, 18, 46, 44, 42, 32, 29, 28, 76, 21, 24, 18, 12, 13, 261]
#
# Generation: 25, Cost time: 6683.65ms
#  	fitness: valid cnt: 1000, max: 103.4935, min: -316.8003, mean: 31.9385, std: 116.1907
#
# 	node counts: max: 11, min: 5, mean: 6.79
#  	conn counts: max: 9, min: 0, mean: 3.44
#  	species: 20, [82, 10, 68, 12, 57, 112, 22, 59, 34, 40, 40, 35, 22, 26, 22, 34, 19, 8, 24, 274]
#
# Generation: 26, Cost time: 6967.34ms
#  	fitness: valid cnt: 1000, max: 104.7505, min: -318.8295, mean: 40.6176, std: 106.9526
#
# 	node counts: max: 11, min: 5, mean: 6.66
#  	conn counts: max: 9, min: 0, mean: 3.41
#  	species: 20, [96, 68, 57, 3, 51, 38, 78, 67, 26, 168, 25, 28, 19, 23, 24, 8, 8, 50, 11, 152]
#
# Generation: 27, Cost time: 6966.88ms
#  	fitness: valid cnt: 1000, max: 104.6758, min: -309.9521, mean: 38.3792, std: 106.8680
#
# 	node counts: max: 11, min: 5, mean: 6.79
#  	conn counts: max: 9, min: 0, mean: 3.66
#  	species: 20, [68, 99, 36, 45, 10, 28, 70, 17, 62, 35, 29, 27, 35, 28, 66, 19, 12, 99, 7, 208]
#
# Generation: 28, Cost time: 7121.74ms
#  	fitness: valid cnt: 1000, max: 104.4739, min: -309.6258, mean: 28.5978, std: 114.1946
#
# 	node counts: max: 11, min: 5, mean: 6.75
#  	conn counts: max: 9, min: 0, mean: 3.71
#  	species: 20, [18, 65, 80, 73, 92, 63, 37, 9, 42, 36, 70, 30, 58, 33, 11, 19, 12, 14, 21, 217]
#
# Generation: 29, Cost time: 7115.08ms
#  	fitness: valid cnt: 1000, max: 104.6173, min: -312.8896, mean: 32.0218, std: 112.2756
#
# 	node counts: max: 12, min: 5, mean: 6.73
#  	conn counts: max: 10, min: 0, mean: 3.54
#  	species: 20, [79, 76, 91, 81, 24, 78, 23, 43, 82, 1, 49, 19, 37, 21, 23, 20, 13, 13, 11, 216]
#
# Generation: 30, Cost time: 6920.01ms
#  	fitness: valid cnt: 1000, max: 104.5508, min: -317.4665, mean: 34.2099, std: 111.5801
#
# 	node counts: max: 13, min: 5, mean: 6.78
#  	conn counts: max: 10, min: 0, mean: 3.74
#  	species: 20, [108, 55, 23, 70, 63, 67, 8, 57, 35, 29, 44, 22, 27, 27, 56, 19, 14, 10, 9, 257]
#
# Generation: 31, Cost time: 6666.60ms
#  	fitness: valid cnt: 1000, max: 105.9533, min: -315.8540, mean: 27.1762, std: 116.0828
#
# 	node counts: max: 11, min: 5, mean: 6.75
#  	conn counts: max: 8, min: 0, mean: 3.57
#  	species: 20, [73, 73, 78, 8, 71, 54, 91, 11, 20, 38, 25, 51, 19, 10, 23, 62, 4, 12, 1, 276]
#
# Generation: 32, Cost time: 6915.09ms
#  	fitness: valid cnt: 1000, max: 105.3638, min: -308.4668, mean: 34.7329, std: 110.6808
#
# 	node counts: max: 11, min: 5, mean: 6.74
#  	conn counts: max: 8, min: 0, mean: 3.65
#  	species: 20, [27, 73, 65, 61, 70, 53, 53, 92, 23, 21, 3, 32, 26, 27, 23, 3, 2, 4, 1, 341]
#
# Generation: 33, Cost time: 6656.73ms
#  	fitness: valid cnt: 1000, max: 104.9090, min: -311.5112, mean: 29.3285, std: 115.6079
#
# 	node counts: max: 11, min: 5, mean: 6.73
#  	conn counts: max: 9, min: 0, mean: 3.67
#  	species: 20, [82, 76, 63, 87, 63, 59, 25, 98, 51, 40, 32, 29, 16, 26, 9, 19, 5, 1, 19, 200]
#
# Generation: 34, Cost time: 6635.17ms
#  	fitness: valid cnt: 1000, max: 106.1530, min: -331.1632, mean: 17.3329, std: 125.9173
#
# 	node counts: max: 11, min: 5, mean: 6.95
#  	conn counts: max: 9, min: 0, mean: 4.15
#  	species: 20, [80, 74, 71, 64, 104, 37, 28, 1, 77, 37, 34, 68, 9, 24, 16, 18, 16, 1, 4, 237]
#
# Generation: 35, Cost time: 7054.34ms
#  	fitness: valid cnt: 1000, max: 105.1989, min: -322.2479, mean: 18.4119, std: 123.2756
#
# 	node counts: max: 12, min: 5, mean: 7.02
#  	conn counts: max: 10, min: 0, mean: 4.03
#  	species: 20, [83, 58, 84, 81, 61, 74, 56, 5, 5, 88, 34, 24, 30, 20, 13, 19, 7, 20, 1, 237]
#
# Generation limit reached!
# Finished: agent has been trained.
# Collecting 1000 data points using the trained agent policy...
# 2025-09-07 21:22:03.735156: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-09-07 21:22:03.735172: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# Causal expert data collection finished.
#
#
# Training and sampling agent #2/2
#
# Starting Agent Training and Data Collection
# Configuring and training the agent...
# Query dimension for sampling:  4
# initializing
# initializing finished
# start compile
# compile finished, cost time: 33.997189s
# Generation: 1, Cost time: 6965.30ms
#  	fitness: valid cnt: 1000, max: 101.6768, min: -314.9246, mean: -206.7634, std: 96.8780
#
# 	node counts: max: 7, min: 5, mean: 6.05
#  	conn counts: max: 7, min: 0, mean: 4.60
#  	species: 20, [517, 4, 88, 19, 73, 38, 1, 106, 2, 1, 2, 1, 7, 1, 2, 19, 1, 2, 3, 113]
#
# Generation: 2, Cost time: 6978.18ms
#  	fitness: valid cnt: 1000, max: 102.6004, min: -325.9275, mean: -107.7709, std: 147.4068
#
# 	node counts: max: 8, min: 5, mean: 6.15
#  	conn counts: max: 8, min: 0, mean: 4.30
#  	species: 20, [100, 43, 75, 1, 110, 84, 188, 41, 26, 21, 21, 79, 13, 13, 4, 8, 8, 3, 3, 159]
#
# Generation: 3, Cost time: 6921.65ms
#  	fitness: valid cnt: 1000, max: 102.6053, min: -309.0288, mean: 5.7238, std: 137.4328
#
# 	node counts: max: 9, min: 5, mean: 6.25
#  	conn counts: max: 9, min: 0, mean: 4.09
#  	species: 20, [64, 130, 2, 57, 25, 39, 55, 72, 35, 38, 60, 106, 36, 23, 16, 3, 4, 2, 1, 232]
#
# Generation: 4, Cost time: 7002.33ms
#  	fitness: valid cnt: 1000, max: 102.4054, min: -312.7181, mean: 22.6309, std: 128.4448
#
# 	node counts: max: 9, min: 5, mean: 6.39
#  	conn counts: max: 9, min: 0, mean: 4.27
#  	species: 20, [99, 52, 57, 5, 10, 38, 126, 47, 39, 40, 19, 34, 36, 44, 73, 17, 2, 6, 2, 254]
#
# Generation: 5, Cost time: 6954.58ms
#  	fitness: valid cnt: 1000, max: 102.3046, min: -315.1070, mean: 33.7325, std: 120.1619
#
# 	node counts: max: 10, min: 5, mean: 6.54
#  	conn counts: max: 9, min: 0, mean: 4.39
#  	species: 20, [133, 55, 29, 56, 78, 50, 48, 50, 4, 34, 23, 38, 29, 34, 35, 20, 1, 9, 1, 273]
#
# Generation: 6, Cost time: 7046.07ms
#  	fitness: valid cnt: 1000, max: 102.9346, min: -312.6598, mean: 31.0803, std: 122.8295
#
# 	node counts: max: 10, min: 5, mean: 6.67
#  	conn counts: max: 10, min: 0, mean: 4.66
#  	species: 20, [74, 56, 111, 56, 6, 51, 7, 56, 38, 50, 37, 39, 28, 30, 33, 22, 14, 8, 1, 283]
#
# Generation: 7, Cost time: 7046.72ms
#  	fitness: valid cnt: 1000, max: 102.7191, min: -320.1427, mean: 26.5178, std: 124.1165
#
# 	node counts: max: 10, min: 5, mean: 6.78
#  	conn counts: max: 11, min: 0, mean: 4.73
#  	species: 20, [62, 22, 37, 50, 44, 28, 55, 45, 36, 40, 50, 3, 44, 84, 44, 29, 16, 9, 7, 295]
#
# Generation: 8, Cost time: 6981.54ms
#  	fitness: valid cnt: 1000, max: 102.3693, min: -311.7057, mean: 38.0134, std: 114.3187
#
# 	node counts: max: 11, min: 5, mean: 6.75
#  	conn counts: max: 11, min: 0, mean: 4.42
#  	species: 20, [102, 48, 65, 88, 53, 1, 5, 39, 48, 47, 14, 37, 41, 22, 19, 14, 17, 20, 1, 319]
#
# Generation: 9, Cost time: 7147.95ms
#  	fitness: valid cnt: 1000, max: 103.4844, min: -312.2413, mean: 41.9809, std: 111.4750
#
# 	node counts: max: 11, min: 5, mean: 6.79
#  	conn counts: max: 11, min: 0, mean: 4.34
#  	species: 20, [25, 66, 49, 61, 5, 2, 54, 91, 48, 26, 50, 38, 25, 31, 17, 32, 30, 4, 42, 304]
#
# Generation: 10, Cost time: 6638.86ms
#  	fitness: valid cnt: 1000, max: 102.5970, min: -307.8713, mean: 38.9144, std: 115.0681
#
# 	node counts: max: 12, min: 5, mean: 6.63
#  	conn counts: max: 11, min: 0, mean: 3.87
#  	species: 20, [37, 1, 52, 46, 64, 49, 116, 2, 50, 50, 44, 34, 28, 15, 15, 24, 25, 5, 5, 338]
#
# Generation: 11, Cost time: 6703.05ms
#  	fitness: valid cnt: 1000, max: 102.6921, min: -314.4196, mean: 46.8996, std: 105.2452
#
# 	node counts: max: 11, min: 5, mean: 6.64
#  	conn counts: max: 9, min: 0, mean: 3.83
#  	species: 20, [141, 4, 50, 56, 54, 50, 60, 30, 31, 34, 17, 39, 22, 31, 38, 7, 11, 6, 10, 309]
#
# Generation: 12, Cost time: 6730.54ms
#  	fitness: valid cnt: 1000, max: 102.6666, min: -317.1755, mean: 40.2006, std: 113.4989
#
# 	node counts: max: 12, min: 5, mean: 6.70
#  	conn counts: max: 10, min: 0, mean: 3.91
#  	species: 20, [141, 58, 5, 56, 60, 35, 53, 45, 31, 27, 45, 23, 30, 31, 23, 32, 16, 7, 8, 274]
#
# Generation: 13, Cost time: 6684.37ms
#  	fitness: valid cnt: 1000, max: 102.4887, min: -320.6611, mean: 36.7173, std: 113.7600
#
# 	node counts: max: 13, min: 5, mean: 6.81
#  	conn counts: max: 11, min: 0, mean: 3.92
#  	species: 20, [55, 46, 3, 46, 60, 62, 47, 52, 44, 37, 113, 23, 24, 23, 23, 6, 19, 21, 14, 282]
#
# Generation: 14, Cost time: 6830.73ms
#  	fitness: valid cnt: 1000, max: 102.5464, min: -319.3615, mean: 41.8378, std: 112.9313
#
# 	node counts: max: 13, min: 5, mean: 6.78
#  	conn counts: max: 11, min: 0, mean: 3.72
#  	species: 20, [123, 39, 7, 47, 55, 54, 44, 53, 42, 18, 47, 41, 12, 10, 32, 21, 18, 22, 29, 286]
#
# Generation: 15, Cost time: 6855.57ms
#  	fitness: valid cnt: 1000, max: 103.1036, min: -310.0750, mean: 39.8191, std: 114.4750
#
# 	node counts: max: 12, min: 5, mean: 6.69
#  	conn counts: max: 10, min: 0, mean: 3.60
#  	species: 20, [70, 3, 122, 50, 40, 19, 11, 44, 5, 27, 29, 31, 29, 27, 36, 31, 33, 14, 21, 358]
#
# Generation: 16, Cost time: 7069.92ms
#  	fitness: valid cnt: 1000, max: 102.2412, min: -308.5964, mean: 44.8793, std: 109.7657
#
# 	node counts: max: 13, min: 5, mean: 6.83
#  	conn counts: max: 11, min: 0, mean: 3.62
#  	species: 20, [46, 61, 59, 137, 22, 45, 47, 32, 42, 27, 36, 29, 16, 11, 26, 18, 8, 21, 22, 295]
#
# Generation: 17, Cost time: 7123.41ms
#  	fitness: valid cnt: 1000, max: 103.6923, min: -333.8529, mean: 48.0941, std: 105.8318
#
# 	node counts: max: 10, min: 5, mean: 6.87
#  	conn counts: max: 9, min: 0, mean: 3.72
#  	species: 20, [140, 18, 49, 44, 60, 10, 40, 50, 29, 42, 26, 30, 29, 35, 29, 4, 9, 20, 14, 322]
#
# Generation: 18, Cost time: 6936.03ms
#  	fitness: valid cnt: 1000, max: 102.4454, min: -310.9853, mean: 44.7907, std: 109.3550
#
# 	node counts: max: 10, min: 5, mean: 6.91
#  	conn counts: max: 10, min: 0, mean: 3.82
#  	species: 20, [68, 70, 45, 43, 52, 119, 5, 40, 56, 3, 39, 29, 23, 23, 16, 3, 30, 8, 2, 326]
#
# Generation: 19, Cost time: 6929.85ms
#  	fitness: valid cnt: 1000, max: 102.5933, min: -309.5459, mean: 49.9657, std: 103.6000
#
# 	node counts: max: 10, min: 5, mean: 6.87
#  	conn counts: max: 9, min: 0, mean: 3.71
#  	species: 20, [10, 38, 116, 73, 24, 41, 55, 55, 29, 37, 33, 18, 25, 23, 23, 19, 1, 25, 27, 328]
#
# Generation: 20, Cost time: 6928.34ms
#  	fitness: valid cnt: 1000, max: 102.4814, min: -313.2598, mean: 46.9712, std: 107.6453
#
# 	node counts: max: 10, min: 5, mean: 7.04
#  	conn counts: max: 11, min: 0, mean: 3.95
#  	species: 20, [58, 122, 53, 53, 62, 37, 4, 2, 30, 22, 20, 50, 27, 19, 21, 17, 15, 42, 50, 296]
#
# Generation: 21, Cost time: 6964.55ms
#  	fitness: valid cnt: 1000, max: 102.4036, min: -327.3581, mean: 47.7650, std: 107.2024
#
# 	node counts: max: 11, min: 5, mean: 7.14
#  	conn counts: max: 11, min: 0, mean: 4.02
#  	species: 20, [79, 5, 57, 52, 43, 30, 38, 56, 94, 36, 33, 22, 47, 40, 22, 20, 15, 28, 4, 279]
#
# Generation: 22, Cost time: 6992.32ms
#  	fitness: valid cnt: 1000, max: 102.8110, min: -313.9620, mean: 30.2081, std: 124.9781
#
# 	node counts: max: 11, min: 5, mean: 7.18
#  	conn counts: max: 12, min: 0, mean: 3.80
#  	species: 20, [63, 8, 100, 6, 70, 49, 41, 58, 35, 33, 41, 36, 36, 36, 28, 20, 12, 18, 26, 284]
#
# Generation: 23, Cost time: 6960.44ms
#  	fitness: valid cnt: 1000, max: 103.2629, min: -315.7555, mean: 47.6543, std: 108.5203
#
# 	node counts: max: 11, min: 5, mean: 7.25
#  	conn counts: max: 12, min: 0, mean: 3.83
#  	species: 20, [2, 16, 46, 126, 52, 52, 28, 31, 39, 33, 57, 13, 22, 19, 34, 16, 18, 13, 22, 361]
#
# Generation: 24, Cost time: 7012.43ms
#  	fitness: valid cnt: 1000, max: 102.4542, min: -307.0866, mean: 46.7831, std: 107.0765
#
# 	node counts: max: 12, min: 5, mean: 7.39
#  	conn counts: max: 13, min: 0, mean: 3.61
#  	species: 20, [5, 53, 64, 27, 46, 127, 44, 34, 34, 48, 20, 29, 29, 25, 22, 22, 15, 6, 4, 346]
#
# Generation: 25, Cost time: 6941.74ms
#  	fitness: valid cnt: 1000, max: 102.4819, min: -312.5197, mean: 46.1768, std: 106.6926
#
# 	node counts: max: 13, min: 5, mean: 7.28
#  	conn counts: max: 13, min: 0, mean: 3.31
#  	species: 20, [4, 64, 46, 65, 46, 37, 134, 43, 46, 15, 24, 48, 14, 19, 23, 39, 7, 3, 18, 305]
#
# Generation: 26, Cost time: 7035.54ms
#  	fitness: valid cnt: 1000, max: 102.5825, min: -322.7159, mean: 51.6190, std: 102.1677
#
# 	node counts: max: 12, min: 5, mean: 7.17
#  	conn counts: max: 14, min: 0, mean: 2.95
#  	species: 20, [18, 137, 72, 38, 61, 55, 29, 21, 28, 31, 38, 37, 39, 12, 14, 10, 8, 4, 22, 326]
#
# Generation: 27, Cost time: 6992.82ms
#  	fitness: valid cnt: 1000, max: 102.1668, min: -310.9996, mean: 53.4160, std: 100.2992
#
# 	node counts: max: 12, min: 5, mean: 7.28
#  	conn counts: max: 14, min: 0, mean: 3.25
#  	species: 20, [51, 67, 46, 130, 52, 47, 3, 46, 37, 42, 27, 27, 17, 24, 9, 1, 22, 11, 9, 332]
#
# Generation: 28, Cost time: 7020.65ms
#  	fitness: valid cnt: 1000, max: 103.2956, min: -308.2833, mean: 57.3740, std: 95.4450
#
# 	node counts: max: 12, min: 5, mean: 7.38
#  	conn counts: max: 13, min: 0, mean: 3.37
#  	species: 20, [73, 59, 3, 44, 119, 46, 37, 40, 37, 39, 20, 26, 19, 29, 16, 13, 14, 1, 4, 361]
#
# Generation: 29, Cost time: 7032.29ms
#  	fitness: valid cnt: 1000, max: 102.8799, min: -308.4984, mean: 48.2463, std: 107.3421
#
# 	node counts: max: 12, min: 5, mean: 7.30
#  	conn counts: max: 14, min: 0, mean: 3.00
#  	species: 20, [1, 42, 43, 51, 31, 64, 52, 134, 29, 45, 37, 21, 45, 15, 26, 12, 15, 5, 8, 324]
#
# Generation: 30, Cost time: 7009.93ms
#  	fitness: valid cnt: 1000, max: 102.5234, min: -305.8103, mean: 50.8056, std: 102.3255
#
# 	node counts: max: 12, min: 5, mean: 7.16
#  	conn counts: max: 14, min: 0, mean: 2.49
#  	species: 20, [46, 37, 50, 47, 42, 46, 78, 34, 40, 38, 35, 33, 50, 40, 8, 15, 10, 12, 1, 338]
#
# Generation: 31, Cost time: 7035.01ms
#  	fitness: valid cnt: 1000, max: 102.1565, min: -308.9660, mean: 62.2923, std: 87.7352
#
# 	node counts: max: 12, min: 5, mean: 6.97
#  	conn counts: max: 14, min: 0, mean: 2.14
#  	species: 20, [60, 52, 14, 45, 69, 38, 103, 45, 32, 30, 27, 31, 23, 18, 29, 35, 8, 9, 1, 331]
#
# Generation: 32, Cost time: 7045.77ms
#  	fitness: valid cnt: 1000, max: 102.9136, min: -310.2331, mean: 65.1720, std: 82.0318
#
# 	node counts: max: 12, min: 5, mean: 6.97
#  	conn counts: max: 16, min: 0, mean: 2.08
#  	species: 20, [67, 63, 17, 62, 48, 46, 48, 31, 70, 16, 14, 25, 22, 24, 15, 29, 28, 25, 1, 349]
#
# Generation: 33, Cost time: 7033.43ms
#  	fitness: valid cnt: 1000, max: 102.6543, min: -308.0291, mean: 64.6164, std: 82.1809
#
# 	node counts: max: 11, min: 5, mean: 7.17
#  	conn counts: max: 14, min: 0, mean: 2.53
#  	species: 20, [35, 1, 47, 56, 52, 37, 75, 101, 33, 24, 27, 42, 12, 17, 20, 26, 19, 16, 1, 359]
#
# Generation: 34, Cost time: 7054.95ms
#  	fitness: valid cnt: 1000, max: 102.7068, min: -304.6367, mean: 63.5942, std: 84.0584
#
# 	node counts: max: 12, min: 5, mean: 7.37
#  	conn counts: max: 14, min: 0, mean: 2.68
#  	species: 20, [37, 51, 123, 37, 30, 93, 63, 41, 32, 24, 27, 27, 21, 24, 20, 16, 3, 2, 28, 301]
#
# Generation: 35, Cost time: 6996.48ms
#  	fitness: valid cnt: 1000, max: 102.8235, min: -307.3409, mean: 62.8238, std: 85.6595
#
# 	node counts: max: 12, min: 5, mean: 7.41
#  	conn counts: max: 15, min: 0, mean: 2.77
#  	species: 20, [67, 64, 68, 35, 33, 10, 134, 38, 60, 29, 28, 34, 18, 30, 22, 21, 19, 8, 2, 280]
#
# Generation limit reached!
# Finished: agent has been trained.
# Collecting 1000 data points using the trained agent policy...
# Causal expert data collection finished.
#
# Data collection complete. Combined data from 2 trained agents.
# Shape of each run's data: (1000, 35)
# Shape of combined trained agents data: (2000, 35)

# %% [markdown]
# ### Data Sampling Method 2: Random Policy
#
# Now, we will sample data from the environment with a random action policy.

# %%
key, random_key = jax.random.split(key)
num_random_sampling_steps = num_trained_agent_sampling * config["data_sampling"]["sampling_steps"]
random_data = collect_random_policy_data(env_problem, random_key, num_random_sampling_steps)
# Out:
# Starting data collection for 2000 steps using a random policy...
# Causal data collection finished.

# %%
data_sources = {
    "trained": combined_trained_agent_data,
    "random": random_data
}

analysis_io_coors = defaultdict(lambda: defaultdict(dict))

# %%
with open(f"{OUTPUT_DIR}/data_sources.pkl", "wb") as f:
    pickle.dump(data_sources, f)
